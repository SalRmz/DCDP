# %% [markdown]
# <a href="https://colab.research.google.com/github/DCDPUAEM/DCDP/blob/main/01%20Programaci%C3%B3n%20en%20Python/notebooks/exercises/Practica_Final_EDA_WoAns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ¿Qué es el análisis exploratorio de datos?
#
# <font color=red>Es un enfoque para resumir, visualizar y familiarizarse con las características de un conjunto de datos.</font>

# %% [markdown]
# ### Valor del análisis de datos exploratorios
#
# El **Análisis Exploratorio de Datos** (<font color=red>EDA</font>) es importante en todos nuestros proyectos de ciencia de datos porque nos permite validar y verificar la información que estamos procesando.
#
# Tener mayor certeza en las relaciones que pudieran existir entre las variables nos puede ayudar a acercarnos a resultados más "certeros", con una mejor interpretación y, en algunas circunstancias, encontrar <font color=blue> información que quizá no era evidente o descubrir que las  que no valía la pena investigar, aportan algo más al proyecto.</font>

# %% [markdown]
# Además, se realiza para **definir y refinar** la selección de variables (características) que se utilizarán para el aprendizaje automático.

# %% [markdown]
# ### Métodos de análisis exploratorio de datos
#
# Siempre es mejor explorar cada conjunto de datos usando múltiples técnicas exploratorias y comparar los resultados.
#
# El análisis exploratorio de datos se realiza principalmente utilizando métodos como:
#
#    * *Visualización univariada* — proporciona estadísticas resumidas para cada campo en el conjunto de datos sin procesar
#    * *Visualización bivariada* — se realiza para encontrar la relación entre cada variable en el conjunto de datos y la variable objetivo de interés
#    * *Visualización multivariada* — se realiza para comprender las interacciones entre diferentes campos en el conjunto de datos
#    * *Reducción de dimensionalidad* — ayuda a comprender los campos de los datos que explican la mayor variación entre las observaciones y permiten el procesamiento de un volumen reducido de datos.
#
# ---
# ---

# %% [markdown]
# En resumen
#
#    * Objetivos de la EDA
#        * Descubrir patrones
#        * Detectar anomalías
#        * Planteamiento de las hipótesis
#        * Comprobar supuestos
#
#    * Cosas hechas durante EDA
#        * Tendencias
#        * Distribución
#        * Medidas de tendencia central
#        * Medidas de dispersion
#        * Correlaciones
#        * Evaluación de la hipótesis
#        * Exploración visual

# %% [markdown]
# # Proyectos

# %% [markdown]
# Puntos a cubrir:
#
# El estudiante deberá presentar una notebook limpia con los análisis realizados al conjunto de datos propuesto del módulo 1.
#
# Nota: Aplica de la misma manera si desean utilizar un conjunto diferente de datos.
#
# Cada sección deberá estar debidamente descrita, así como cada función auxiliar que se emplee en el proceso de análisis: que variables utiliza, que se hace, que retorna.

# %% [markdown]
# ### Importando las librerías requeridas para EDA
#
# A continuación se encuentran las bibliotecas que se utilizan para realizar EDA (análisis exploratorio de datos) en este ejercicio.

# %%
# Data manipulation libraries
import pandas as pd
import numpy as np
# Data visualization 
import matplotlib.pyplot as plt
import seaborn as sns
# Web scraping 
from bs4 import BeautifulSoup

# %% [markdown]
# ### Cargar los datos
#
# A continuación trabajaremos con un dataset que contiene 800 registros y diferentes características: 5 de tipo categórico y 7 de tipo numérico.

# %%
## Lectura de datos
pokemondf = pd.read_csv("../../data/Pokemon.csv")
## Impresion de dimensiones
pokemondf.shape
# Out:
# (800, 13)

# %% [markdown]
# Para el siguiente análisis, deberán realizar las siguientes indicaciones:
#
#     1.- Mostrar el tipo de variables que contiene este archivo.
#
#     2.- Descartar columnas innecesarias, aquellas que consideren que no aportarán algo especial para el análisis exploratorio.
#
#     3.- Mostrar una tabla de frecuencias de la columna "Generation" y hacer un plot que muestre cada una de ellas. Considerando valores y porcentajes
#
#     4.- Realizar un filtro para generar un dataframe a partir de la columna "Generation".
#
#     5.- Buscar elementos duplicados y descartarlos - Podrían utilizar la función ".str.contains()"

# %%
# Tipo de variables
pokemondf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
# Descarte de columna (s)
pokemondf.drop('#', axis=1, inplace=True)
pokemondf.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# Tabla de frecuencias con gráfico
plt.figure(figsize=(7,7))
pokemondf.Generation.value_counts().plot.pie(title="Generaciones")
pokemondf.Generation.value_counts()
# Out:
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: Generation, dtype: int64

# %%
# Tabla de frecuencias relativas con gráfico
#pokemondf.Generation.value_counts().sum()
plt.figure(figsize=(9,9))
(pokemondf.Generation.value_counts()/(len(pokemondf.index))*100)   .plot.barh()
(pokemondf.Generation.value_counts()/(len(pokemondf.index))*100)
# Out:
# 1    20.750
# 5    20.625
# 3    20.000
# 4    15.125
# 2    13.250
# 6    10.250
# Name: Generation, dtype: float64

# %%
# Filtro de columna Generation
gens1and2 = pokemondf[(pokemondf.Generation==1) | (pokemondf.Generation==2)]
print(gens1and2.Generation.value_counts().index.values)
print(gens1and2.shape)
# Out:
# [1 2]
# (272, 12)

# %% [markdown]
# Posiblemente podamos encontrar repetidos dadas las caracteristicas de algunos de los datos que tenemos en este conjunto... podemos usar la función pd.duplicated() para hacer la comprobación.

# %%
# Sección auxiliar...
print('Hay  0 nombres duplicados en el dataset, debe ser algo más...')
print('Número de numbres únicos:',len(pokemondf['Name'].unique()))
print('Aha! Necesitamos eliminar a los que tienen "MEGA" en su nombre. Vamos a quitarlos')
# Out:
# Hay  0 nombres duplicados en el dataset, debe ser algo más...
# Número de numbres únicos: 800
# Aha! Necesitamos eliminar a los que tienen "MEGA" en su nombre. Vamos a quitarlos

# %% [markdown]
# Filtremos aquellos que tienen palabras extra...

# %%
# Elementos duplicados y descarte
#gens1and2[pokemondf.Name.str.contains('Mega')]
mega_filter = (gens1and2.Name.str.contains('Mega '))
gens1and2 = gens1and2[~mega_filter]
#gens1and2.Generation.value_counts()
print(gens1and2.groupby('Generation').size() ,'\nOk vamos bien!')
# Out:
# Generation
# 1    151
# 2    100
# dtype: int64
# Ok vamos bien!

# %% [markdown]
# ¡Bien!, En este momento deberíamos tener 251 elementos en nuestro dataframe. ahora realizaremos un análisis exploratorio general del mismo para entender mediante estadística y visualización, el comportamiento de los mismos.

# %% [markdown]
# ### Atributos del dataset y cómo se relacionan entre sí
#
# Como tenemos 251 elementos y 6 atributos para cada uno de ellos, analizaremos cómo se relacionan entre sí.
#
# ![img](https://www.centropkmn.com/wp-content/uploads/2016/07/cpokemon.com_entrenamiento_extremo-749x450.jpg)
#
# ¿Los Pokémon con mayor defensa también tienen un mayor ataque? ¿Los Pokémon rápidos también son buenos defensivamente?
#
# Con ese fin, usaremos un par de cuadrículas de Seaborn. Es una cuadrícula bastante personalizable donde puede mapear diferentes tipos de gráficos en el triángulo superior, triángulo inferior y ejes diagonales.
# La figura producida tiene tres secciones:
#
#     Triángulo superior -> Diagrama de dispersión para cada pokemon  (diagrama de dispersión SCATTERPLOT de Seaborn)
#     Diagonal -> Gráfico de densidad de kernel para cada atributo (Seabon KDEPLOT)
#     Triángulo inferior -> Gráfico de dispersión con un ajuste de modelo de regresión lineal (gráfico REGPLOT de Seaborn)

# %%
def my_pairgrid(gens1and2):
    plt.rcParams["axes.labelsize"] = 20
    g = sns.PairGrid(gens1and2, vars=['HP','Attack','Defense','Sp. Atk','Sp. Def','Speed'])
    g = g.map_diag(sns.kdeplot, shade=True)
    g = g.map_lower(sns.regplot, scatter_kws={'alpha':0.3})
    g = g.map_upper(sns.scatterplot)
    return(g)
_ = my_pairgrid(gens1and2)

# %% [markdown]
# ### Correlación entre atributos
#
# Si bien el primer gráfico fue útil, quizás una mejor manera de visualizar la correlación entre atributos es un mapa de calor con un azul más fuerte que indica una correlación más alta.

# %%
# Corr de todo el dataset (todas las generaciones)
plt.figure(figsize=(9,9))
my_corr = pokemondf.corr() 
mask = np.zeros_like(my_corr) 
## Esta parte es para llenar la diagonal superior de espacios en blanco!
mask[np.triu_indices_from(mask)] = True 
with sns.axes_style("white"):
     ax = sns.heatmap(my_corr, mask=mask, square=True, cmap=sns.color_palette('mako'), vmax=np.max(np.sort(my_corr.values)[:,-2]), linewidths=0.3)

# %%
# Corr de gens 1 y 2
plt.figure(figsize=(9,9))
my_corr = gens1and2.corr() 
mask = np.zeros_like(my_corr) 
## Esta parte es para llenar la diagonal superior de espacios en blanco!
mask[np.triu_indices_from(mask)] = True 
with sns.axes_style("white"):
     ax = sns.heatmap(my_corr, mask=mask, square=True, cmap=sns.color_palette('mako'), vmax=np.max(np.sort(my_corr.values)[:,-2]), linewidths=0.3)

# %% [markdown]
# # Análisis de atributos y tipos
#
# Hagamos un análisis de cómo los atributos varían con el tipo.
# Mi primera idea fue usar un Seaborn scatterplot ya que no tenemos tantos datos que puedan saturar la imagen.
#
# Asignar quien es x, y, data y hue al usar el método de sns.scatterplot() y colocar el título adecuadamente

# %%
fig = plt.figure(figsize=(11,9))
#plt.rcParams["font.size"] = 25
#a = sns.scatterplot(data=gens1and2[(gens1and2.Generation==1)], x="HP", y="Type 1", alpha=.7, palette="muted",s=70, hue='Generation')
#b = sns.scatterplot(data=gens1and2[(gens1and2.Generation==2)], x="HP", y="Type 1", alpha=.7, palette="muted",s=70, hue='Generation')
a = sns.scatterplot(data=gens1and2[(gens1and2.Generation==1)], x="HP", y="Type 1", alpha=.7, palette="muted",s=70)
b = sns.scatterplot(data=gens1and2[(gens1and2.Generation==2)], x="HP", y="Type 1", alpha=.7, palette="muted",s=70)
a.set_title('HP contra Tipo 1 y Generación para los colores')
plt.show()
gens1and2
# Out:
#            Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0     Bulbasaur    Grass  Poison    318   45      49       49       65
# 1       Ivysaur    Grass  Poison    405   60      62       63       80
# 2      Venusaur    Grass  Poison    525   80      82       83      100
# 4    Charmander     Fire     NaN    309   39      52       43       60
# 5    Charmeleon     Fire     NaN    405   58      64       58       80
# ..          ...      ...     ...    ...  ...     ...      ...      ...
# 266     Pupitar     Rock  Ground    410   70      84       70       65
# 267   Tyranitar     Rock    Dark    600  100     134      110       95
# 269       Lugia  Psychic  Flying    680  106      90      130       90
# 270       Ho-oh     Fire  Flying    680  106     130       90      110
# 271      Celebi  Psychic   Grass    600  100     100      100      100
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# 1         80     60           1      False
# 2        100     80           1      False
# 4         50     65           1      False
# 5         65     80           1      False
# ..       ...    ...         ...        ...
# 266       70     51           2      False
# 267      100     61           2      False
# 269      154    110           2       True
# 270      154     90           2       True
# 271      100    100           2      False
#
# [251 rows x 12 columns]

# %%
a = #<Completa>
#<Completa>
plt.show()

# %% [markdown]
# Además de los valores atípicos, vamos a transformar el tipo "Fairy" a "Normal", por cuestiones de practicidad. En ambas columnas "Type 1" y "Type 2"

# %%
# Cambiar valores en las dos columnas solicitadas
gens1and2.loc[ (gens1and2['Type 1']=='Fairy') | (gens1and2['Type 2']=='Fairy'), ['Type 1','Type 2'] ] = 'Normal'
gens1and2.loc[ (gens1and2['Type 1']=='Fairy') | (gens1and2['Type 2']=='Fairy') ]
# Out:
# Empty DataFrame
# Columns: [Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
#Completa la función y trata de describir lo que hace
def attr_per_type(input_df, y_attr, hue_attr,type_number):
    fig = plt.figure(figsize=(10,10))
    plt.rcParams["font.size"] = 30
    f, axes = plt.subplots(2, 3, figsize=(20, 20), sharey=True, sharex=True)
    poke_attributes = input_df[y_attr]
    counter = 0
    for row in range(2):
        for col in range(3):
            sns.boxplot(y = type_number, x = y_attr[counter], data=input_df, ax=axes[row, col], showfliers=False)
            sns.scatterplot(y=type_number, x=y_attr[counter], data=input_df, ax=axes[row, col], hue=hue_attr, palette=['black', 'orange'])

            counter += 1
            #if (col == 0):
            #    axes[row, col].yaxis.label.set_visible(False)
            #    continue
            #axes[row, col].yaxis.set_visible(False)
    return(f, axes)
                        
# Manda a llamar la funcion con el dataframe correspondiente y las columnas tipos y legendario
(f, axes) = attr_per_type(gens1and2, ['HP','Defense','Sp. Def','Speed','Attack','Sp. Atk'], 'Legendary','Type 1')
plt.show()

# %%
(f, axes) = attr_per_type(gens1and2, ['HP','Defense','Sp. Def','Speed','Attack','Sp. Atk'], 'Legendary','Type 2')
plt.show()

# %% [markdown]
# Muy bien, esto se ve mucho mejor! El problema con el conjunto de datos actual es que incluye Pokémon de menor evolución. Por ejemplo, Charmander, Charmeleon y Charizard están todos incluidos. Preferiría que solo se incluyera el último Pokémon de evolución porque la selección se realiza principalmente en función de esos. Tratemos de solucionar este problema raspando el árbol de evolución de Pokémon del sitio web de pokemondb.

# %% [markdown]
# Voy a desglosar cada paso para que sea más comprensible.
# ---
#
# ### Web scraping para mejorar nuestro conjunto de datos
#
# **Paso 1: encontrar la URL**
#
# El sitio web que elegí es el sitio web de pokemondb que enumera las evoluciones de todos los Pokémon en esta forma:
#
# ![img](https://i.postimg.cc/qR8yX0qW/Pika.png)

# %%
poke_url = 'https://pokemondb.net/evolution#evo-g2'
#Hacer el get y el parseo correspondiente
from bs4 import BeautifulSoup
import requests
pdb_response = requests.get(poke_url)
pdb_response
# Out:
# <Response [200]>

# %% [markdown]
# **Paso 2: examinar el HTML de la página y extraer los datos**
#
# Ahora que tenemos el HTML, tenemos que examinar dónde se encuentra exactamente la información que queremos. Podemos utilizar las herramientas de desarrollo de Google Chrome para ver qué parte del árbol HTML nos interesa. Usaremos el método de find_all.
#
# ![img](https://i.postimg.cc/qRf8WwFf/Pika-HTML.png)

# %%
html_soup = BeautifulSoup(pdb_response.text, 'html.parser')
infocards = html_soup.find_all("div", {"class":"infocard-list-evo"})
infocards[0]
# Out:
# <div class="infocard-list-evo"><div class="infocard"><span class="infocard-lg-img"><a href="/pokedex/bulbasaur"><span class="img-fixed img-sprite" data-alt="Bulbasaur sprite" data-avif="https://img.pokemondb.net/sprites/home/normal/2x/avif/bulbasaur.avif" data-src="https://img.pokemondb.net/sprites/home/normal/2x/bulbasaur.jpg"></span></a></span><span class="infocard-lg-data text-muted"><small>#0001</small><br/> <a class="ent-name" href="/pokedex/bulbasaur">Bulbasaur</a><br/> <small><a class="itype grass" href="/type/grass">Grass</a> · <a class="itype poison" href="/type/poison">Poison</a></small></span></div>
# <span class="infocard infocard-arrow"><i class="icon-arrow icon-arrow-e"></i><small>(Level 16)</small></span><div class="infocard"><span class="infocard-lg-img"><a href="/pokedex/ivysaur"><span class="img-fixed img-sprite" data-alt="Ivysaur sprite" data-avif="https://img.pokemondb.net/sprites/home/normal/2x/avif/ivysaur.avif" data-src="https://img.pokemondb.net/sprites/home/normal/2x/ivysaur.jpg"></span></a></span><span class="infocard-lg-data text-muted"><small>#0002</small><br/> <a class="ent-name" href="/pokedex/ivysaur">Ivysaur</a><br/> <small><a class="itype grass" href="/type/grass">Grass</a> · <a class="itype poison" href="/type/poison">Poison</a></small></span></div>
# <span class="infocard infocard-arrow"><i class="icon-arrow icon-arrow-e"></i><small>(Level 32)</small></span><div class="infocard"><span class="infocard-lg-img"><a href="/pokedex/venusaur"><span class="img-fixed img-sprite" data-alt="Venusaur sprite" data-avif="https://img.pokemondb.net/sprites/home/normal/2x/avif/venusaur.avif" data-src="https://img.pokemondb.net/sprites/home/normal/2x/venusaur.jpg"></span></a></span><span class="infocard-lg-data text-muted"><small>#0003</small><br/> <a class="ent-name" href="/pokedex/venusaur">Venusaur</a><br/> <small><a class="itype grass" href="/type/grass">Grass</a> · <a class="itype poison" href="/type/poison">Poison</a></small></span></div>
# </div>

# %% [markdown]
# **Paso 3: localizar y extraer toda la información útil en el HTML**
#
# Ahora que hemos seleccionado todos los divs, necesitamos extraer la información que nos sea útil. Me gustaría obtener la siguiente información:
#
#     La evolución es el pokemon (1º, 2º, etc.)
#     El número de Pokémon (lo necesitaremos en el futuro para filtrar)
#     El texto pequeño debajo del pokemon (nuevamente, esto se usará para filtrar)
#     El nombre de pokemon
#
# Toda la información que queremos se puede encontrar en el intervalo con la clase 'infocard-lg-data text-muted' como se puede ver en la captura de pantalla a continuación:
#
# ![img](https://i.postimg.cc/yxh1vgJp/Info-Pic.png)

# %% [markdown]
# Solo necesitamos extraer el primer pequeño (número de pokemon), el segundo pequeño (nombre de pokemon) y la etiqueta a con la clase 'ent-name' que tiene el texto pequeño debajo del pokemon.
#
# También utilizo enumerate para crear un índice de la evolución del pokemon. Entonces, por ejemplo, en los casos simples (Charmander -> Charmeleon -> Charizard) con enumerate logro darle a Charmander el número 1, Charmeleon el número 2 y Charizard el número 3.
#
# Desafortunadamente, esto falla estrepitosamente para los casos complejos (como el de Pikatchu) pero trataremos esto en un paso posterior.

# %%
raw = []
for chain in infocards:
    raw.append(([(i, x.find('small').getText(), 
                  x.find_all('small')[1].getText(), 
                  x.find('a', {'class':'ent-name'}).getText()) for i, x in enumerate(list(chain.find_all('span', {'class':'infocard-lg-data text-muted'})), 1)]))

raw[:4]
# Out:
# [[(1, '#0001', 'Grass · Poison', 'Bulbasaur'),
#   (2, '#0002', 'Grass · Poison', 'Ivysaur'),
#   (3, '#0003', 'Grass · Poison', 'Venusaur')],
#  [(1, '#0004', 'Fire', 'Charmander'),
#   (2, '#0005', 'Fire', 'Charmeleon'),
#   (3, '#0006', 'Fire · Flying', 'Charizard')],
#  [(1, '#0007', 'Water', 'Squirtle'),
#   (2, '#0008', 'Water', 'Wartortle'),
#   (3, '#0009', 'Water', 'Blastoise')],
#  [(1, '#0010', 'Bug', 'Caterpie'),
#   (2, '#0011', 'Bug', 'Metapod'),
#   (3, '#0012', 'Bug · Flying', 'Butterfree')]]

# %% [markdown]
# **Paso 4: limpieza del conjunto de datos**
#
# Ahora que hemos extraído los datos, definitivamente necesitamos hacer algunos filtros:
#
#     Eliminar todos los Pokémon que tienen 'alolan' en su nombre, ya que son de generaciones más nuevas, supongo.
#     Elimina todos los Pokémon con un número superior a 251, ya que estos son nuevamente de generaciones más nuevas.
#     Elimine todas las entradas restantes que tengan 1 o menos entradas de la lista

# %%
raw[7]
# Out:
# [(1, '#0019', 'Alolan Rattata', 'Rattata'),
#  (2, '#0020', 'Alolan Raticate', 'Raticate')]

# %%
#Eliminar todas las tuplas que contienen "Alol" en el texto 
step_1 = [[elem for elem in branch_list if 'Alol' not in elem[2]] for branch_list in raw]

step_1
# Out:
# [[(1, '#0001', 'Grass · Poison', 'Bulbasaur'),
#   (2, '#0002', 'Grass · Poison', 'Ivysaur'),
#   (3, '#0003', 'Grass · Poison', 'Venusaur')],
#  [(1, '#0004', 'Fire', 'Charmander'),
#   (2, '#0005', 'Fire', 'Charmeleon'),
#   (3, '#0006', 'Fire · Flying', 'Charizard')],
#  [(1, '#0007', 'Water', 'Squirtle'),
#   (2, '#0008', 'Water', 'Wartortle'),
#   (3, '#0009', 'Water', 'Blastoise')],
#  [(1, '#0010', 'Bug', 'Caterpie'),
#   (2, '#0011', 'Bug', 'Metapod'),
#   (3, '#0012', 'Bug · Flying', 'Butterfree')],
#  [(1, '#0013', 'Bug · Poison', 'Weedle'),
#   (2, '#0014', 'Bug · Poison', 'Kakuna'),
#   (3, '#0015', 'Bug · Poison', 'Beedrill')],
#  [(1, '#0016', 'Normal · Flying', 'Pidgey'),
#   (2, '#0017', 'Normal · Flying', 'Pidgeotto'),
#   (3, '#0018', 'Normal · Flying', 'Pidgeot')],
#  [(1, '#0019', 'Normal', 'Rattata'), (2, '#0020', 'Normal', 'Raticate')],
#  [],
#  [(1, '#0021', 'Normal · Flying', 'Spearow'),
#   (2, '#0022', 'Normal · Flying', 'Fearow')],
#  [(1, '#0023', 'Poison', 'Ekans'), (2, '#0024', 'Poison', 'Arbok')],
#  [(1, '#0172', 'Electric', 'Pichu'),
#   (2, '#0025', 'Electric', 'Pikachu'),
#   (3, '#0026', 'Electric', 'Raichu')],
#  [(1, '#0026', 'Electric', 'Raichu')],
#  [],
#  [(1, '#0027', 'Ground', 'Sandshrew'), (2, '#0028', 'Ground', 'Sandslash')],
#  [],
#  [(1, '#0029', 'Poison', 'Nidoran♀'),
#   (2, '#0030', 'Poison', 'Nidorina'),
#   (3, '#0031', 'Poison · Ground', 'Nidoqueen')],
#  [(1, '#0032', 'Poison', 'Nidoran♂'),
#   (2, '#0033', 'Poison', 'Nidorino'),
#   (3, '#0034', 'Poison · Ground', 'Nidoking')],
#  [(1, '#0173', 'Fairy', 'Cleffa'),
#   (2, '#0035', 'Fairy', 'Clefairy'),
#   (3, '#0036', 'Fairy', 'Clefable')],
#  [(1, '#0037', 'Fire', 'Vulpix'), (2, '#0038', 'Fire', 'Ninetales')],
#  [],
#  [(1, '#0174', 'Normal · Fairy', 'Igglybuff'),
#   (2, '#0039', 'Normal · Fairy', 'Jigglypuff'),
#   (3, '#0040', 'Normal · Fairy', 'Wigglytuff')],
#  [(1, '#0041', 'Poison · Flying', 'Zubat'),
#   (2, '#0042', 'Poison · Flying', 'Golbat'),
#   (3, '#0169', 'Poison · Flying', 'Crobat')],
#  [(1, '#0043', 'Grass · Poison', 'Oddish'),
#   (2, '#0044', 'Grass · Poison', 'Gloom'),
#   (3, '#0045', 'Grass · Poison', 'Vileplume'),
#   (4, '#0182', 'Grass', 'Bellossom')],
#  [(1, '#0045', 'Grass · Poison', 'Vileplume')],
#  [(1, '#0182', 'Grass', 'Bellossom')],
#  [(1, '#0046', 'Bug · Grass', 'Paras'),
#   (2, '#0047', 'Bug · Grass', 'Parasect')],
#  [(1, '#0048', 'Bug · Poison', 'Venonat'),
#   (2, '#0049', 'Bug · Poison', 'Venomoth')],
#  [(1, '#0050', 'Ground', 'Diglett'), (2, '#0051', 'Ground', 'Dugtrio')],
#  [],
#  [(1, '#0052', 'Normal', 'Meowth'), (2, '#0053', 'Normal', 'Persian')],
#  [],
#  [(1, '#0052', 'Galarian Meowth', 'Meowth'),
#   (2, '#0863', 'Steel', 'Perrserker')],
#  [(1, '#0054', 'Water', 'Psyduck'), (2, '#0055', 'Water', 'Golduck')],
#  [(1, '#0056', 'Fighting', 'Mankey'),
#   (2, '#0057', 'Fighting', 'Primeape'),
#   (3, '#0979', 'Fighting · Ghost', 'Annihilape')],
#  [(1, '#0058', 'Fire', 'Growlithe'), (2, '#0059', 'Fire', 'Arcanine')],
#  [(1, '#0058', 'Hisuian Growlithe', 'Growlithe'),
#   (2, '#0059', 'Hisuian Arcanine', 'Arcanine')],
#  [(1, '#0060', 'Water', 'Poliwag'),
#   (2, '#0061', 'Water', 'Poliwhirl'),
#   (3, '#0062', 'Water · Fighting', 'Poliwrath'),
#   (4, '#0186', 'Water', 'Politoed')],
#  [(1, '#0062', 'Water · Fighting', 'Poliwrath')],
#  [(1, '#0186', 'Water', 'Politoed')],
#  [(1, '#0063', 'Psychic', 'Abra'),
#   (2, '#0064', 'Psychic', 'Kadabra'),
#   (3, '#0065', 'Psychic', 'Alakazam')],
#  [(1, '#0066', 'Fighting', 'Machop'),
#   (2, '#0067', 'Fighting', 'Machoke'),
#   (3, '#0068', 'Fighting', 'Machamp')],
#  [(1, '#0069', 'Grass · Poison', 'Bellsprout'),
#   (2, '#0070', 'Grass · Poison', 'Weepinbell'),
#   (3, '#0071', 'Grass · Poison', 'Victreebel')],
#  [(1, '#0072', 'Water · Poison', 'Tentacool'),
#   (2, '#0073', 'Water · Poison', 'Tentacruel')],
#  [(1, '#0074', 'Rock · Ground', 'Geodude'),
#   (2, '#0075', 'Rock · Ground', 'Graveler'),
#   (3, '#0076', 'Rock · Ground', 'Golem')],
#  [],
#  [(1, '#0077', 'Fire', 'Ponyta'), (2, '#0078', 'Fire', 'Rapidash')],
#  [(1, '#0077', 'Galarian Ponyta', 'Ponyta'),
#   (2, '#0078', 'Galarian Rapidash', 'Rapidash')],
#  [(1, '#0079', 'Water · Psychic', 'Slowpoke'),
#   (2, '#0080', 'Water · Psychic', 'Slowbro'),
#   (3, '#0199', 'Water · Psychic', 'Slowking')],
#  [(1, '#0080', 'Water · Psychic', 'Slowbro')],
#  [(1, '#0199', 'Water · Psychic', 'Slowking')],
#  [(1, '#0079', 'Galarian Slowpoke', 'Slowpoke'),
#   (2, '#0080', 'Galarian Slowbro', 'Slowbro'),
#   (3, '#0199', 'Galarian Slowking', 'Slowking')],
#  [(1, '#0080', 'Galarian Slowbro', 'Slowbro')],
#  [(1, '#0199', 'Galarian Slowking', 'Slowking')],
#  [(1, '#0081', 'Electric · Steel', 'Magnemite'),
#   (2, '#0082', 'Electric · Steel', 'Magneton'),
#   (3, '#0462', 'Electric · Steel', 'Magnezone')],
#  [(1, '#0084', 'Normal · Flying', 'Doduo'),
#   (2, '#0085', 'Normal · Flying', 'Dodrio')],
#  [(1, '#0086', 'Water', 'Seel'), (2, '#0087', 'Water · Ice', 'Dewgong')],
#  [(1, '#0088', 'Poison', 'Grimer'), (2, '#0089', 'Poison', 'Muk')],
#  [],
#  [(1, '#0090', 'Water', 'Shellder'), (2, '#0091', 'Water · Ice', 'Cloyster')],
#  [(1, '#0092', 'Ghost · Poison', 'Gastly'),
#   (2, '#0093', 'Ghost · Poison', 'Haunter'),
#   (3, '#0094', 'Ghost · Poison', 'Gengar')],
#  [(1, '#0095', 'Rock · Ground', 'Onix'),
#   (2, '#0208', 'Steel · Ground', 'Steelix')],
#  [(1, '#0096', 'Psychic', 'Drowzee'), (2, '#0097', 'Psychic', 'Hypno')],
#  [(1, '#0098', 'Water', 'Krabby'), (2, '#0099', 'Water', 'Kingler')],
#  [(1, '#0100', 'Electric', 'Voltorb'), (2, '#0101', 'Electric', 'Electrode')],
#  [(1, '#0100', 'Hisuian Voltorb', 'Voltorb'),
#   (2, '#0101', 'Hisuian Electrode', 'Electrode')],
#  [(1, '#0102', 'Grass · Psychic', 'Exeggcute'),
#   (2, '#0103', 'Grass · Psychic', 'Exeggutor')],
#  [(1, '#0103', 'Grass · Psychic', 'Exeggutor')],
#  [],
#  [(1, '#0104', 'Ground', 'Cubone'), (2, '#0105', 'Ground', 'Marowak')],
#  [(1, '#0105', 'Ground', 'Marowak')],
#  [],
#  [(1, '#0236', 'Fighting', 'Tyrogue'),
#   (2, '#0106', 'Fighting', 'Hitmonlee'),
#   (3, '#0107', 'Fighting', 'Hitmonchan'),
#   (4, '#0237', 'Fighting', 'Hitmontop')],
#  [(1, '#0106', 'Fighting', 'Hitmonlee')],
#  [(1, '#0107', 'Fighting', 'Hitmonchan')],
#  [(1, '#0237', 'Fighting', 'Hitmontop')],
#  [(1, '#0108', 'Normal', 'Lickitung'), (2, '#0463', 'Normal', 'Lickilicky')],
#  [(1, '#0109', 'Poison', 'Koffing'),
#   (2, '#0110', 'Poison', 'Weezing'),
#   (3, '#0110', 'Galarian Weezing', 'Weezing')],
#  [(1, '#0110', 'Poison', 'Weezing')],
#  [(1, '#0110', 'Galarian Weezing', 'Weezing')],
#  [(1, '#0111', 'Ground · Rock', 'Rhyhorn'),
#   (2, '#0112', 'Ground · Rock', 'Rhydon'),
#   (3, '#0464', 'Ground · Rock', 'Rhyperior')],
#  [(1, '#0440', 'Normal', 'Happiny'),
#   (2, '#0113', 'Normal', 'Chansey'),
#   (3, '#0242', 'Normal', 'Blissey')],
#  [(1, '#0114', 'Grass', 'Tangela'), (2, '#0465', 'Grass', 'Tangrowth')],
#  [(1, '#0116', 'Water', 'Horsea'),
#   (2, '#0117', 'Water', 'Seadra'),
#   (3, '#0230', 'Water · Dragon', 'Kingdra')],
#  [(1, '#0118', 'Water', 'Goldeen'), (2, '#0119', 'Water', 'Seaking')],
#  [(1, '#0120', 'Water', 'Staryu'), (2, '#0121', 'Water · Psychic', 'Starmie')],
#  [(1, '#0439', 'Psychic · Fairy', 'Mime Jr.'),
#   (2, '#0122', 'Psychic · Fairy', 'Mr. Mime'),
#   (3, '#0122', 'Galarian Mr. Mime', 'Mr. Mime'),
#   (4, '#0866', 'Ice · Psychic', 'Mr. Rime')],
#  [(1, '#0122', 'Psychic · Fairy', 'Mr. Mime')],
#  [(1, '#0122', 'Galarian Mr. Mime', 'Mr. Mime'),
#   (2, '#0866', 'Ice · Psychic', 'Mr. Rime')],
#  [(1, '#0123', 'Bug · Flying', 'Scyther'),
#   (2, '#0212', 'Bug · Steel', 'Scizor'),
#   (3, '#0900', 'Bug · Rock', 'Kleavor')],
#  [(1, '#0212', 'Bug · Steel', 'Scizor')],
#  [(1, '#0900', 'Bug · Rock', 'Kleavor')],
#  [(1, '#0238', 'Ice · Psychic', 'Smoochum'),
#   (2, '#0124', 'Ice · Psychic', 'Jynx')],
#  [(1, '#0239', 'Electric', 'Elekid'),
#   (2, '#0125', 'Electric', 'Electabuzz'),
#   (3, '#0466', 'Electric', 'Electivire')],
#  [(1, '#0240', 'Fire', 'Magby'),
#   (2, '#0126', 'Fire', 'Magmar'),
#   (3, '#0467', 'Fire', 'Magmortar')],
#  [(1, '#0129', 'Water', 'Magikarp'),
#   (2, '#0130', 'Water · Flying', 'Gyarados')],
#  [(1, '#0133', 'Normal', 'Eevee'),
#   (2, '#0134', 'Water', 'Vaporeon'),
#   (3, '#0135', 'Electric', 'Jolteon'),
#   (4, '#0136', 'Fire', 'Flareon')],
#  [(1, '#0134', 'Water', 'Vaporeon')],
#  [(1, '#0135', 'Electric', 'Jolteon')],
#  [(1, '#0136', 'Fire', 'Flareon')],
#  [(1, '#0133', 'Normal', 'Eevee'),
#   (2, '#0196', 'Psychic', 'Espeon'),
#   (3, '#0197', 'Dark', 'Umbreon')],
#  [(1, '#0196', 'Psychic', 'Espeon')],
#  [(1, '#0197', 'Dark', 'Umbreon')],
#  [(1, '#0133', 'Normal', 'Eevee'),
#   (2, '#0470', 'Grass', 'Leafeon'),
#   (3, '#0471', 'Ice', 'Glaceon')],
#  [(1, '#0470', 'Grass', 'Leafeon')],
#  [(1, '#0471', 'Ice', 'Glaceon')],
#  [(1, '#0133', 'Normal', 'Eevee'), (2, '#0700', 'Fairy', 'Sylveon')],
#  [(1, '#0137', 'Normal', 'Porygon'),
#   (2, '#0233', 'Normal', 'Porygon2'),
#   (3, '#0474', 'Normal', 'Porygon-Z')],
#  [(1, '#0138', 'Rock · Water', 'Omanyte'),
#   (2, '#0139', 'Rock · Water', 'Omastar')],
#  [(1, '#0140', 'Rock · Water', 'Kabuto'),
#   (2, '#0141', 'Rock · Water', 'Kabutops')],
#  [(1, '#0446', 'Normal', 'Munchlax'), (2, '#0143', 'Normal', 'Snorlax')],
#  [(1, '#0147', 'Dragon', 'Dratini'),
#   (2, '#0148', 'Dragon', 'Dragonair'),
#   (3, '#0149', 'Dragon · Flying', 'Dragonite')],
#  [(1, '#0152', 'Grass', 'Chikorita'),
#   (2, '#0153', 'Grass', 'Bayleef'),
#   (3, '#0154', 'Grass', 'Meganium')],
#  [(1, '#0155', 'Fire', 'Cyndaquil'),
#   (2, '#0156', 'Fire', 'Quilava'),
#   (3, '#0157', 'Fire', 'Typhlosion'),
#   (4, '#0157', 'Hisuian Typhlosion', 'Typhlosion')],
#  [(1, '#0157', 'Fire', 'Typhlosion')],
#  [(1, '#0157', 'Hisuian Typhlosion', 'Typhlosion')],
#  [(1, '#0158', 'Water', 'Totodile'),
#   (2, '#0159', 'Water', 'Croconaw'),
#   (3, '#0160', 'Water', 'Feraligatr')],
#  [(1, '#0161', 'Normal', 'Sentret'), (2, '#0162', 'Normal', 'Furret')],
#  [(1, '#0163', 'Normal · Flying', 'Hoothoot'),
#   (2, '#0164', 'Normal · Flying', 'Noctowl')],
#  [(1, '#0165', 'Bug · Flying', 'Ledyba'),
#   (2, '#0166', 'Bug · Flying', 'Ledian')],
#  [(1, '#0167', 'Bug · Poison', 'Spinarak'),
#   (2, '#0168', 'Bug · Poison', 'Ariados')],
#  [(1, '#0170', 'Water · Electric', 'Chinchou'),
#   (2, '#0171', 'Water · Electric', 'Lanturn')],
#  [(1, '#0175', 'Fairy', 'Togepi'),
#   (2, '#0176', 'Fairy · Flying', 'Togetic'),
#   (3, '#0468', 'Fairy · Flying', 'Togekiss')],
#  [(1, '#0177', 'Psychic · Flying', 'Natu'),
#   (2, '#0178', 'Psychic · Flying', 'Xatu')],
#  [(1, '#0179', 'Electric', 'Mareep'),
#   (2, '#0180', 'Electric', 'Flaaffy'),
#   (3, '#0181', 'Electric', 'Ampharos')],
#  [(1, '#0298', 'Normal · Fairy', 'Azurill'),
#   (2, '#0183', 'Water · Fairy', 'Marill'),
#   (3, '#0184', 'Water · Fairy', 'Azumarill')],
#  [(1, '#0438', 'Rock', 'Bonsly'), (2, '#0185', 'Rock', 'Sudowoodo')],
#  [(1, '#0187', 'Grass · Flying', 'Hoppip'),
#   (2, '#0188', 'Grass · Flying', 'Skiploom'),
#   (3, '#0189', 'Grass · Flying', 'Jumpluff')],
#  [(1, '#0190', 'Normal', 'Aipom'), (2, '#0424', 'Normal', 'Ambipom')],
#  [(1, '#0191', 'Grass', 'Sunkern'), (2, '#0192', 'Grass', 'Sunflora')],
#  [(1, '#0193', 'Bug · Flying', 'Yanma'),
#   (2, '#0469', 'Bug · Flying', 'Yanmega')],
#  [(1, '#0194', 'Water · Ground', 'Wooper'),
#   (2, '#0195', 'Water · Ground', 'Quagsire')],
#  [(1, '#0194', 'Paldean Wooper', 'Wooper'),
#   (2, '#0980', 'Poison · Ground', 'Clodsire')],
#  [(1, '#0198', 'Dark · Flying', 'Murkrow'),
#   (2, '#0430', 'Dark · Flying', 'Honchkrow')],
#  [(1, '#0200', 'Ghost', 'Misdreavus'), (2, '#0429', 'Ghost', 'Mismagius')],
#  [(1, '#0360', 'Psychic', 'Wynaut'), (2, '#0202', 'Psychic', 'Wobbuffet')],
#  [(1, '#0204', 'Bug', 'Pineco'), (2, '#0205', 'Bug · Steel', 'Forretress')],
#  [(1, '#0207', 'Ground · Flying', 'Gligar'),
#   (2, '#0472', 'Ground · Flying', 'Gliscor')],
#  [(1, '#0209', 'Fairy', 'Snubbull'), (2, '#0210', 'Fairy', 'Granbull')],
#  [(1, '#0215', 'Dark · Ice', 'Sneasel'),
#   (2, '#0461', 'Dark · Ice', 'Weavile')],
#  [(1, '#0215', 'Hisuian Sneasel', 'Sneasel'),
#   (2, '#0903', 'Fighting · Poison', 'Sneasler')],
#  [(1, '#0216', 'Normal', 'Teddiursa'),
#   (2, '#0217', 'Normal', 'Ursaring'),
#   (3, '#0901', 'Ground · Normal', 'Ursaluna')],
#  [(1, '#0218', 'Fire', 'Slugma'), (2, '#0219', 'Fire · Rock', 'Magcargo')],
#  [(1, '#0220', 'Ice · Ground', 'Swinub'),
#   (2, '#0221', 'Ice · Ground', 'Piloswine'),
#   (3, '#0473', 'Ice · Ground', 'Mamoswine')],
#  [(1, '#0223', 'Water', 'Remoraid'), (2, '#0224', 'Water', 'Octillery')],
#  [(1, '#0458', 'Water · Flying', 'Mantyke'),
#   (2, '#0226', 'Water · Flying', 'Mantine')],
#  [(1, '#0228', 'Dark · Fire', 'Houndour'),
#   (2, '#0229', 'Dark · Fire', 'Houndoom')],
#  [(1, '#0231', 'Ground', 'Phanpy'), (2, '#0232', 'Ground', 'Donphan')],
#  [(1, '#0246', 'Rock · Ground', 'Larvitar'),
#   (2, '#0247', 'Rock · Ground', 'Pupitar'),
#   (3, '#0248', 'Rock · Dark', 'Tyranitar')],
#  [(1, '#0234', 'Normal', 'Stantler'),
#   (2, '#0899', 'Normal · Psychic', 'Wyrdeer')],
#  [(1, '#0203', 'Normal · Psychic', 'Girafarig'),
#   (2, '#0981', 'Normal · Psychic', 'Farigiraf')],
#  [(1, '#0206', 'Normal', 'Dunsparce'),
#   (2, '#0982', 'Two-Segment Form', 'Dudunsparce'),
#   (3, '#0982', 'Three-Segment Form', 'Dudunsparce')],
#  [(1, '#0982', 'Two-Segment Form', 'Dudunsparce')],
#  [(1, '#0982', 'Three-Segment Form', 'Dudunsparce')],
#  [(1, '#0252', 'Grass', 'Treecko'),
#   (2, '#0253', 'Grass', 'Grovyle'),
#   (3, '#0254', 'Grass', 'Sceptile')],
#  [(1, '#0255', 'Fire', 'Torchic'),
#   (2, '#0256', 'Fire · Fighting', 'Combusken'),
#   (3, '#0257', 'Fire · Fighting', 'Blaziken')],
#  [(1, '#0258', 'Water', 'Mudkip'),
#   (2, '#0259', 'Water · Ground', 'Marshtomp'),
#   (3, '#0260', 'Water · Ground', 'Swampert')],
#  [(1, '#0261', 'Dark', 'Poochyena'), (2, '#0262', 'Dark', 'Mightyena')],
#  [(1, '#0263', 'Normal', 'Zigzagoon'), (2, '#0264', 'Normal', 'Linoone')],
#  [(1, '#0263', 'Galarian Zigzagoon', 'Zigzagoon'),
#   (2, '#0264', 'Galarian Linoone', 'Linoone'),
#   (3, '#0862', 'Dark · Normal', 'Obstagoon')],
#  [(1, '#0265', 'Bug', 'Wurmple'),
#   (2, '#0266', 'Bug', 'Silcoon'),
#   (3, '#0267', 'Bug · Flying', 'Beautifly'),
#   (4, '#0268', 'Bug', 'Cascoon'),
#   (5, '#0269', 'Bug · Poison', 'Dustox')],
#  [(1, '#0266', 'Bug', 'Silcoon'), (2, '#0267', 'Bug · Flying', 'Beautifly')],
#  [(1, '#0268', 'Bug', 'Cascoon'), (2, '#0269', 'Bug · Poison', 'Dustox')],
#  [(1, '#0270', 'Water · Grass', 'Lotad'),
#   (2, '#0271', 'Water · Grass', 'Lombre'),
#   (3, '#0272', 'Water · Grass', 'Ludicolo')],
#  [(1, '#0273', 'Grass', 'Seedot'),
#   (2, '#0274', 'Grass · Dark', 'Nuzleaf'),
#   (3, '#0275', 'Grass · Dark', 'Shiftry')],
#  [(1, '#0276', 'Normal · Flying', 'Taillow'),
#   (2, '#0277', 'Normal · Flying', 'Swellow')],
#  [(1, '#0278', 'Water · Flying', 'Wingull'),
#   (2, '#0279', 'Water · Flying', 'Pelipper')],
#  [(1, '#0280', 'Psychic · Fairy', 'Ralts'),
#   (2, '#0281', 'Psychic · Fairy', 'Kirlia'),
#   (3, '#0282', 'Psychic · Fairy', 'Gardevoir'),
#   (4, '#0475', 'Psychic · Fighting', 'Gallade')],
#  [(1, '#0282', 'Psychic · Fairy', 'Gardevoir')],
#  [(1, '#0475', 'Psychic · Fighting', 'Gallade')],
#  [(1, '#0283', 'Bug · Water', 'Surskit'),
#   (2, '#0284', 'Bug · Flying', 'Masquerain')],
#  [(1, '#0285', 'Grass', 'Shroomish'),
#   (2, '#0286', 'Grass · Fighting', 'Breloom')],
#  [(1, '#0287', 'Normal', 'Slakoth'),
#   (2, '#0288', 'Normal', 'Vigoroth'),
#   (3, '#0289', 'Normal', 'Slaking')],
#  [(1, '#0290', 'Bug · Ground', 'Nincada'),
#   (2, '#0291', 'Bug · Flying', 'Ninjask'),
#   (3, '#0291', 'Bug · Flying', 'Ninjask'),
#   (4, '#0292', 'Bug · Ghost', 'Shedinja')],
#  [(1, '#0291', 'Bug · Flying', 'Ninjask')],
#  [(1, '#0291', 'Bug · Flying', 'Ninjask'),
#   (2, '#0292', 'Bug · Ghost', 'Shedinja')],
#  [(1, '#0293', 'Normal', 'Whismur'),
#   (2, '#0294', 'Normal', 'Loudred'),
#   (3, '#0295', 'Normal', 'Exploud')],
#  [(1, '#0296', 'Fighting', 'Makuhita'), (2, '#0297', 'Fighting', 'Hariyama')],
#  [(1, '#0299', 'Rock', 'Nosepass'), (2, '#0476', 'Rock · Steel', 'Probopass')],
#  [(1, '#0300', 'Normal', 'Skitty'), (2, '#0301', 'Normal', 'Delcatty')],
#  [(1, '#0304', 'Steel · Rock', 'Aron'),
#   (2, '#0305', 'Steel · Rock', 'Lairon'),
#   (3, '#0306', 'Steel · Rock', 'Aggron')],
#  [(1, '#0307', 'Fighting · Psychic', 'Meditite'),
#   (2, '#0308', 'Fighting · Psychic', 'Medicham')],
#  [(1, '#0309', 'Electric', 'Electrike'),
#   (2, '#0310', 'Electric', 'Manectric')],
#  [(1, '#0406', 'Grass · Poison', 'Budew'),
#   (2, '#0315', 'Grass · Poison', 'Roselia'),
#   (3, '#0407', 'Grass · Poison', 'Roserade')],
#  [(1, '#0316', 'Poison', 'Gulpin'), (2, '#0317', 'Poison', 'Swalot')],
#  [(1, '#0318', 'Water · Dark', 'Carvanha'),
#   (2, '#0319', 'Water · Dark', 'Sharpedo')],
#  [(1, '#0320', 'Water', 'Wailmer'), (2, '#0321', 'Water', 'Wailord')],
#  [(1, '#0322', 'Fire · Ground', 'Numel'),
#   (2, '#0323', 'Fire · Ground', 'Camerupt')],
#  [(1, '#0325', 'Psychic', 'Spoink'), (2, '#0326', 'Psychic', 'Grumpig')],
#  [(1, '#0328', 'Ground', 'Trapinch'),
#   (2, '#0329', 'Ground · Dragon', 'Vibrava'),
#   (3, '#0330', 'Ground · Dragon', 'Flygon')],
#  [(1, '#0331', 'Grass', 'Cacnea'), (2, '#0332', 'Grass · Dark', 'Cacturne')],
#  [(1, '#0333', 'Normal · Flying', 'Swablu'),
#   (2, '#0334', 'Dragon · Flying', 'Altaria')],
#  [(1, '#0339', 'Water · Ground', 'Barboach'),
#   (2, '#0340', 'Water · Ground', 'Whiscash')],
#  [(1, '#0341', 'Water', 'Corphish'),
#   (2, '#0342', 'Water · Dark', 'Crawdaunt')],
#  [(1, '#0343', 'Ground · Psychic', 'Baltoy'),
#   (2, '#0344', 'Ground · Psychic', 'Claydol')],
#  [(1, '#0345', 'Rock · Grass', 'Lileep'),
#   (2, '#0346', 'Rock · Grass', 'Cradily')],
#  [(1, '#0347', 'Rock · Bug', 'Anorith'),
#   (2, '#0348', 'Rock · Bug', 'Armaldo')],
#  [(1, '#0349', 'Water', 'Feebas'), (2, '#0350', 'Water', 'Milotic')],
#  [(1, '#0353', 'Ghost', 'Shuppet'), (2, '#0354', 'Ghost', 'Banette')],
#  [(1, '#0355', 'Ghost', 'Duskull'),
#   (2, '#0356', 'Ghost', 'Dusclops'),
#   (3, '#0477', 'Ghost', 'Dusknoir')],
#  [(1, '#0433', 'Psychic', 'Chingling'), (2, '#0358', 'Psychic', 'Chimecho')],
#  [(1, '#0361', 'Ice', 'Snorunt'),
#   (2, '#0362', 'Ice', 'Glalie'),
#   (3, '#0478', 'Ice · Ghost', 'Froslass')],
#  [(1, '#0362', 'Ice', 'Glalie')],
#  [(1, '#0478', 'Ice · Ghost', 'Froslass')],
#  [(1, '#0363', 'Ice · Water', 'Spheal'),
#   (2, '#0364', 'Ice · Water', 'Sealeo'),
#   (3, '#0365', 'Ice · Water', 'Walrein')],
#  [(1, '#0366', 'Water', 'Clamperl'),
#   (2, '#0367', 'Water', 'Huntail'),
#   (3, '#0368', 'Water', 'Gorebyss')],
#  [(1, '#0367', 'Water', 'Huntail')],
#  [(1, '#0368', 'Water', 'Gorebyss')],
#  [(1, '#0371', 'Dragon', 'Bagon'),
#   (2, '#0372', 'Dragon', 'Shelgon'),
#   (3, '#0373', 'Dragon · Flying', 'Salamence')],
#  [(1, '#0374', 'Steel · Psychic', 'Beldum'),
#   (2, '#0375', 'Steel · Psychic', 'Metang'),
#   (3, '#0376', 'Steel · Psychic', 'Metagross')],
#  [(1, '#0387', 'Grass', 'Turtwig'),
#   (2, '#0388', 'Grass', 'Grotle'),
#   (3, '#0389', 'Grass · Ground', 'Torterra')],
#  [(1, '#0390', 'Fire', 'Chimchar'),
#   (2, '#0391', 'Fire · Fighting', 'Monferno'),
#   (3, '#0392', 'Fire · Fighting', 'Infernape')],
#  [(1, '#0393', 'Water', 'Piplup'),
#   (2, '#0394', 'Water', 'Prinplup'),
#   (3, '#0395', 'Water · Steel', 'Empoleon')],
#  [(1, '#0396', 'Normal · Flying', 'Starly'),
#   (2, '#0397', 'Normal · Flying', 'Staravia'),
#   (3, '#0398', 'Normal · Flying', 'Staraptor')],
#  [(1, '#0399', 'Normal', 'Bidoof'), (2, '#0400', 'Normal · Water', 'Bibarel')],
#  [(1, '#0401', 'Bug', 'Kricketot'), (2, '#0402', 'Bug', 'Kricketune')],
#  [(1, '#0403', 'Electric', 'Shinx'),
#   (2, '#0404', 'Electric', 'Luxio'),
#   (3, '#0405', 'Electric', 'Luxray')],
#  [(1, '#0408', 'Rock', 'Cranidos'), (2, '#0409', 'Rock', 'Rampardos')],
#  [(1, '#0410', 'Rock · Steel', 'Shieldon'),
#   (2, '#0411', 'Rock · Steel', 'Bastiodon')],
#  [(1, '#0412', 'All forms', 'Burmy'), (2, '#0414', 'Bug · Flying', 'Mothim')],
#  [(1, '#0412', 'Plant Cloak', 'Burmy'),
#   (2, '#0413', 'Plant Cloak', 'Wormadam')],
#  [(1, '#0412', 'Sandy Cloak', 'Burmy'),
#   (2, '#0413', 'Sandy Cloak', 'Wormadam')],
#  [(1, '#0412', 'Trash Cloak', 'Burmy'),
#   (2, '#0413', 'Trash Cloak', 'Wormadam')],
#  [(1, '#0415', 'Bug · Flying', 'Combee'),
#   (2, '#0416', 'Bug · Flying', 'Vespiquen')],
#  [(1, '#0418', 'Water', 'Buizel'), (2, '#0419', 'Water', 'Floatzel')],
#  [(1, '#0420', 'Grass', 'Cherubi'), (2, '#0421', 'Grass', 'Cherrim')],
#  [(1, '#0422', 'Water', 'Shellos'),
#   (2, '#0423', 'Water · Ground', 'Gastrodon')],
#  [(1, '#0425', 'Ghost · Flying', 'Drifloon'),
#   (2, '#0426', 'Ghost · Flying', 'Drifblim')],
#  [(1, '#0427', 'Normal', 'Buneary'), (2, '#0428', 'Normal', 'Lopunny')],
#  [(1, '#0431', 'Normal', 'Glameow'), (2, '#0432', 'Normal', 'Purugly')],
#  [(1, '#0434', 'Poison · Dark', 'Stunky'),
#   (2, '#0435', 'Poison · Dark', 'Skuntank')],
#  [(1, '#0436', 'Steel · Psychic', 'Bronzor'),
#   (2, '#0437', 'Steel · Psychic', 'Bronzong')],
#  [(1, '#0443', 'Dragon · Ground', 'Gible'),
#   (2, '#0444', 'Dragon · Ground', 'Gabite'),
#   (3, '#0445', 'Dragon · Ground', 'Garchomp')],
#  [(1, '#0447', 'Fighting', 'Riolu'),
#   (2, '#0448', 'Fighting · Steel', 'Lucario')],
#  [(1, '#0449', 'Ground', 'Hippopotas'), (2, '#0450', 'Ground', 'Hippowdon')],
#  [(1, '#0451', 'Poison · Bug', 'Skorupi'),
#   (2, '#0452', 'Poison · Dark', 'Drapion')],
#  [(1, '#0453', 'Poison · Fighting', 'Croagunk'),
#   (2, '#0454', 'Poison · Fighting', 'Toxicroak')],
#  [(1, '#0456', 'Water', 'Finneon'), (2, '#0457', 'Water', 'Lumineon')],
#  [(1, '#0459', 'Grass · Ice', 'Snover'),
#   (2, '#0460', 'Grass · Ice', 'Abomasnow')],
#  [(1, '#0495', 'Grass', 'Snivy'),
#   (2, '#0496', 'Grass', 'Servine'),
#   (3, '#0497', 'Grass', 'Serperior')],
#  [(1, '#0498', 'Fire', 'Tepig'),
#   (2, '#0499', 'Fire · Fighting', 'Pignite'),
#   (3, '#0500', 'Fire · Fighting', 'Emboar')],
#  [(1, '#0501', 'Water', 'Oshawott'),
#   (2, '#0502', 'Water', 'Dewott'),
#   (3, '#0503', 'Water', 'Samurott'),
#   (4, '#0503', 'Hisuian Samurott', 'Samurott')],
#  [(1, '#0503', 'Water', 'Samurott')],
#  [(1, '#0503', 'Hisuian Samurott', 'Samurott')],
#  [(1, '#0504', 'Normal', 'Patrat'), (2, '#0505', 'Normal', 'Watchog')],
#  [(1, '#0506', 'Normal', 'Lillipup'),
#   (2, '#0507', 'Normal', 'Herdier'),
#   (3, '#0508', 'Normal', 'Stoutland')],
#  [(1, '#0509', 'Dark', 'Purrloin'), (2, '#0510', 'Dark', 'Liepard')],
#  [(1, '#0511', 'Grass', 'Pansage'), (2, '#0512', 'Grass', 'Simisage')],
#  [(1, '#0513', 'Fire', 'Pansear'), (2, '#0514', 'Fire', 'Simisear')],
#  [(1, '#0515', 'Water', 'Panpour'), (2, '#0516', 'Water', 'Simipour')],
#  [(1, '#0517', 'Psychic', 'Munna'), (2, '#0518', 'Psychic', 'Musharna')],
#  [(1, '#0519', 'Normal · Flying', 'Pidove'),
#   (2, '#0520', 'Normal · Flying', 'Tranquill'),
#   (3, '#0521', 'Normal · Flying', 'Unfezant')],
#  [(1, '#0522', 'Electric', 'Blitzle'), (2, '#0523', 'Electric', 'Zebstrika')],
#  [(1, '#0524', 'Rock', 'Roggenrola'),
#   (2, '#0525', 'Rock', 'Boldore'),
#   (3, '#0526', 'Rock', 'Gigalith')],
#  [(1, '#0527', 'Psychic · Flying', 'Woobat'),
#   (2, '#0528', 'Psychic · Flying', 'Swoobat')],
#  [(1, '#0529', 'Ground', 'Drilbur'),
#   (2, '#0530', 'Ground · Steel', 'Excadrill')],
#  [(1, '#0532', 'Fighting', 'Timburr'),
#   (2, '#0533', 'Fighting', 'Gurdurr'),
#   (3, '#0534', 'Fighting', 'Conkeldurr')],
#  [(1, '#0535', 'Water', 'Tympole'),
#   (2, '#0536', 'Water · Ground', 'Palpitoad'),
#   (3, '#0537', 'Water · Ground', 'Seismitoad')],
#  [(1, '#0540', 'Bug · Grass', 'Sewaddle'),
#   (2, '#0541', 'Bug · Grass', 'Swadloon'),
#   (3, '#0542', 'Bug · Grass', 'Leavanny')],
#  [(1, '#0543', 'Bug · Poison', 'Venipede'),
#   (2, '#0544', 'Bug · Poison', 'Whirlipede'),
#   (3, '#0545', 'Bug · Poison', 'Scolipede')],
#  [(1, '#0546', 'Grass · Fairy', 'Cottonee'),
#   (2, '#0547', 'Grass · Fairy', 'Whimsicott')],
#  [(1, '#0548', 'Grass', 'Petilil'),
#   (2, '#0549', 'Grass', 'Lilligant'),
#   (3, '#0549', 'Hisuian Lilligant', 'Lilligant')],
#  [(1, '#0549', 'Grass', 'Lilligant')],
#  [(1, '#0549', 'Hisuian Lilligant', 'Lilligant')],
#  [(1, '#0551', 'Ground · Dark', 'Sandile'),
#   (2, '#0552', 'Ground · Dark', 'Krokorok'),
#   (3, '#0553', 'Ground · Dark', 'Krookodile')],
#  [(1, '#0554', 'Fire', 'Darumaka'),
#   (2, '#0555', 'Standard Mode', 'Darmanitan')],
#  [(1, '#0554', 'Galarian Darumaka', 'Darumaka'),
#   (2, '#0555', 'Galarian Standard Mode', 'Darmanitan')],
#  [(1, '#0557', 'Bug · Rock', 'Dwebble'),
#   (2, '#0558', 'Bug · Rock', 'Crustle')],
#  [(1, '#0559', 'Dark · Fighting', 'Scraggy'),
#   (2, '#0560', 'Dark · Fighting', 'Scrafty')],
#  [(1, '#0562', 'Ghost', 'Yamask'), (2, '#0563', 'Ghost', 'Cofagrigus')],
#  [(1, '#0562', 'Galarian Yamask', 'Yamask'),
#   (2, '#0867', 'Ground · Ghost', 'Runerigus')],
#  [(1, '#0564', 'Water · Rock', 'Tirtouga'),
#   (2, '#0565', 'Water · Rock', 'Carracosta')],
#  [(1, '#0566', 'Rock · Flying', 'Archen'),
#   (2, '#0567', 'Rock · Flying', 'Archeops')],
#  [(1, '#0568', 'Poison', 'Trubbish'), (2, '#0569', 'Poison', 'Garbodor')],
#  [(1, '#0570', 'Dark', 'Zorua'), (2, '#0571', 'Dark', 'Zoroark')],
#  [(1, '#0570', 'Hisuian Zorua', 'Zorua'),
#   (2, '#0571', 'Hisuian Zoroark', 'Zoroark')],
#  [(1, '#0572', 'Normal', 'Minccino'), (2, '#0573', 'Normal', 'Cinccino')],
#  [(1, '#0574', 'Psychic', 'Gothita'),
#   (2, '#0575', 'Psychic', 'Gothorita'),
#   (3, '#0576', 'Psychic', 'Gothitelle')],
#  [(1, '#0577', 'Psychic', 'Solosis'),
#   (2, '#0578', 'Psychic', 'Duosion'),
#   (3, '#0579', 'Psychic', 'Reuniclus')],
#  [(1, '#0580', 'Water · Flying', 'Ducklett'),
#   (2, '#0581', 'Water · Flying', 'Swanna')],
#  [(1, '#0582', 'Ice', 'Vanillite'),
#   (2, '#0583', 'Ice', 'Vanillish'),
#   (3, '#0584', 'Ice', 'Vanilluxe')],
#  [(1, '#0585', 'Normal · Grass', 'Deerling'),
#   (2, '#0586', 'Normal · Grass', 'Sawsbuck')],
#  [(1, '#0588', 'Bug', 'Karrablast'),
#   (2, '#0589', 'Bug · Steel', 'Escavalier')],
#  [(1, '#0590', 'Grass · Poison', 'Foongus'),
#   (2, '#0591', 'Grass · Poison', 'Amoonguss')],
#  [(1, '#0592', 'Water · Ghost', 'Frillish'),
#   (2, '#0593', 'Water · Ghost', 'Jellicent')],
#  [(1, '#0595', 'Bug · Electric', 'Joltik'),
#   (2, '#0596', 'Bug · Electric', 'Galvantula')],
#  [(1, '#0597', 'Grass · Steel', 'Ferroseed'),
#   (2, '#0598', 'Grass · Steel', 'Ferrothorn')],
#  [(1, '#0599', 'Steel', 'Klink'),
#   (2, '#0600', 'Steel', 'Klang'),
#   (3, '#0601', 'Steel', 'Klinklang')],
#  [(1, '#0602', 'Electric', 'Tynamo'),
#   (2, '#0603', 'Electric', 'Eelektrik'),
#   (3, '#0604', 'Electric', 'Eelektross')],
#  [(1, '#0605', 'Psychic', 'Elgyem'), (2, '#0606', 'Psychic', 'Beheeyem')],
#  [(1, '#0607', 'Ghost · Fire', 'Litwick'),
#   (2, '#0608', 'Ghost · Fire', 'Lampent'),
#   (3, '#0609', 'Ghost · Fire', 'Chandelure')],
#  [(1, '#0610', 'Dragon', 'Axew'),
#   (2, '#0611', 'Dragon', 'Fraxure'),
#   (3, '#0612', 'Dragon', 'Haxorus')],
#  [(1, '#0613', 'Ice', 'Cubchoo'), (2, '#0614', 'Ice', 'Beartic')],
#  [(1, '#0616', 'Bug', 'Shelmet'), (2, '#0617', 'Bug', 'Accelgor')],
#  [(1, '#0619', 'Fighting', 'Mienfoo'), (2, '#0620', 'Fighting', 'Mienshao')],
#  [(1, '#0622', 'Ground · Ghost', 'Golett'),
#   (2, '#0623', 'Ground · Ghost', 'Golurk')],
#  [(1, '#0624', 'Dark · Steel', 'Pawniard'),
#   (2, '#0625', 'Dark · Steel', 'Bisharp'),
#   (3, '#0983', 'Dark · Steel', 'Kingambit')],
#  [(1, '#0627', 'Normal · Flying', 'Rufflet'),
#   (2, '#0628', 'Normal · Flying', 'Braviary'),
#   (3, '#0628', 'Hisuian Braviary', 'Braviary')],
#  [(1, '#0628', 'Normal · Flying', 'Braviary')],
#  [(1, '#0628', 'Hisuian Braviary', 'Braviary')],
#  [(1, '#0629', 'Dark · Flying', 'Vullaby'),
#   (2, '#0630', 'Dark · Flying', 'Mandibuzz')],
#  [(1, '#0633', 'Dark · Dragon', 'Deino'),
#   (2, '#0634', 'Dark · Dragon', 'Zweilous'),
#   (3, '#0635', 'Dark · Dragon', 'Hydreigon')],
#  [(1, '#0636', 'Bug · Fire', 'Larvesta'),
#   (2, '#0637', 'Bug · Fire', 'Volcarona')],
#  [(1, '#0650', 'Grass', 'Chespin'),
#   (2, '#0651', 'Grass', 'Quilladin'),
#   (3, '#0652', 'Grass · Fighting', 'Chesnaught')],
#  [(1, '#0653', 'Fire', 'Fennekin'),
#   (2, '#0654', 'Fire', 'Braixen'),
#   (3, '#0655', 'Fire · Psychic', 'Delphox')],
#  [(1, '#0656', 'Water', 'Froakie'),
#   (2, '#0657', 'Water', 'Frogadier'),
#   (3, '#0658', 'Water · Dark', 'Greninja')],
#  [(1, '#0659', 'Normal', 'Bunnelby'),
#   (2, '#0660', 'Normal · Ground', 'Diggersby')],
#  [(1, '#0661', 'Normal · Flying', 'Fletchling'),
#   (2, '#0662', 'Fire · Flying', 'Fletchinder'),
#   (3, '#0663', 'Fire · Flying', 'Talonflame')],
#  [(1, '#0664', 'Bug', 'Scatterbug'),
#   (2, '#0665', 'Bug', 'Spewpa'),
#   (3, '#0666', 'Bug · Flying', 'Vivillon')],
#  [(1, '#0667', 'Fire · Normal', 'Litleo'),
#   (2, '#0668', 'Fire · Normal', 'Pyroar')],
#  [(1, '#0669', 'Fairy', 'Flabébé'),
#   (2, '#0670', 'Fairy', 'Floette'),
#   (3, '#0671', 'Fairy', 'Florges')],
#  [(1, '#0672', 'Grass', 'Skiddo'), (2, '#0673', 'Grass', 'Gogoat')],
#  [(1, '#0674', 'Fighting', 'Pancham'),
#   (2, '#0675', 'Fighting · Dark', 'Pangoro')],
#  [(1, '#0677', 'Psychic', 'Espurr'),
#   (2, '#0678', 'Male', 'Meowstic'),
#   (3, '#0678', 'Female', 'Meowstic')],
#  [(1, '#0678', 'Male', 'Meowstic')],
#  [(1, '#0678', 'Female', 'Meowstic')],
#  [(1, '#0679', 'Steel · Ghost', 'Honedge'),
#   (2, '#0680', 'Steel · Ghost', 'Doublade'),
#   (3, '#0681', 'Steel · Ghost', 'Aegislash')],
#  [(1, '#0682', 'Fairy', 'Spritzee'), (2, '#0683', 'Fairy', 'Aromatisse')],
#  [(1, '#0684', 'Fairy', 'Swirlix'), (2, '#0685', 'Fairy', 'Slurpuff')],
#  [(1, '#0686', 'Dark · Psychic', 'Inkay'),
#   (2, '#0687', 'Dark · Psychic', 'Malamar')],
#  [(1, '#0688', 'Rock · Water', 'Binacle'),
#   (2, '#0689', 'Rock · Water', 'Barbaracle')],
#  [(1, '#0690', 'Poison · Water', 'Skrelp'),
#   (2, '#0691', 'Poison · Dragon', 'Dragalge')],
#  [(1, '#0692', 'Water', 'Clauncher'), (2, '#0693', 'Water', 'Clawitzer')],
#  [(1, '#0694', 'Electric · Normal', 'Helioptile'),
#   (2, '#0695', 'Electric · Normal', 'Heliolisk')],
#  [(1, '#0696', 'Rock · Dragon', 'Tyrunt'),
#   (2, '#0697', 'Rock · Dragon', 'Tyrantrum')],
#  [(1, '#0698', 'Rock · Ice', 'Amaura'), (2, '#0699', 'Rock · Ice', 'Aurorus')],
#  [(1, '#0704', 'Dragon', 'Goomy'),
#   (2, '#0705', 'Dragon', 'Sliggoo'),
#   (3, '#0706', 'Dragon', 'Goodra'),
#   (4, '#0705', 'Hisuian Sliggoo', 'Sliggoo'),
#   (5, '#0706', 'Hisuian Goodra', 'Goodra')],
#  [(1, '#0705', 'Dragon', 'Sliggoo'), (2, '#0706', 'Dragon', 'Goodra')],
#  [(1, '#0705', 'Hisuian Sliggoo', 'Sliggoo'),
#   (2, '#0706', 'Hisuian Goodra', 'Goodra')],
#  [(1, '#0708', 'Ghost · Grass', 'Phantump'),
#   (2, '#0709', 'Ghost · Grass', 'Trevenant')],
#  [(1, '#0710', 'Ghost · Grass', 'Pumpkaboo'),
#   (2, '#0711', 'Ghost · Grass', 'Gourgeist')],
#  [(1, '#0712', 'Ice', 'Bergmite'),
#   (2, '#0713', 'Ice', 'Avalugg'),
#   (3, '#0713', 'Hisuian Avalugg', 'Avalugg')],
#  [(1, '#0713', 'Ice', 'Avalugg')],
#  [(1, '#0713', 'Hisuian Avalugg', 'Avalugg')],
#  [(1, '#0714', 'Flying · Dragon', 'Noibat'),
#   (2, '#0715', 'Flying · Dragon', 'Noivern')],
#  [(1, '#0722', 'Grass · Flying', 'Rowlet'),
#   (2, '#0723', 'Grass · Flying', 'Dartrix'),
#   (3, '#0724', 'Grass · Ghost', 'Decidueye'),
#   (4, '#0724', 'Hisuian Decidueye', 'Decidueye')],
#  [(1, '#0724', 'Grass · Ghost', 'Decidueye')],
#  [(1, '#0724', 'Hisuian Decidueye', 'Decidueye')],
#  [(1, '#0725', 'Fire', 'Litten'),
#   (2, '#0726', 'Fire', 'Torracat'),
#   (3, '#0727', 'Fire · Dark', 'Incineroar')],
#  [(1, '#0728', 'Water', 'Popplio'),
#   (2, '#0729', 'Water', 'Brionne'),
#   (3, '#0730', 'Water · Fairy', 'Primarina')],
#  [(1, '#0731', 'Normal · Flying', 'Pikipek'),
#   (2, '#0732', 'Normal · Flying', 'Trumbeak'),
#   (3, '#0733', 'Normal · Flying', 'Toucannon')],
#  [(1, '#0734', 'Normal', 'Yungoos'), (2, '#0735', 'Normal', 'Gumshoos')],
#  [(1, '#0736', 'Bug', 'Grubbin'),
#   (2, '#0737', 'Bug · Electric', 'Charjabug'),
#   (3, '#0738', 'Bug · Electric', 'Vikavolt')],
#  [(1, '#0739', 'Fighting', 'Crabrawler'),
#   (2, '#0740', 'Fighting · Ice', 'Crabominable')],
#  [(1, '#0742', 'Bug · Fairy', 'Cutiefly'),
#   (2, '#0743', 'Bug · Fairy', 'Ribombee')],
#  [(1, '#0744', 'Rock', 'Rockruff'),
#   (2, '#0745', 'Midday Form', 'Lycanroc'),
#   (3, '#0745', 'Midnight Form', 'Lycanroc')],
#  [(1, '#0745', 'Midday Form', 'Lycanroc')],
#  [(1, '#0745', 'Midnight Form', 'Lycanroc')],
#  [(1, '#0744', 'Own Tempo Rockruff', 'Rockruff'),
#   (2, '#0745', 'Dusk Form', 'Lycanroc')],
#  [(1, '#0747', 'Poison · Water', 'Mareanie'),
#   (2, '#0748', 'Poison · Water', 'Toxapex')],
#  [(1, '#0749', 'Ground', 'Mudbray'), (2, '#0750', 'Ground', 'Mudsdale')],
#  [(1, '#0751', 'Water · Bug', 'Dewpider'),
#   (2, '#0752', 'Water · Bug', 'Araquanid')],
#  [(1, '#0753', 'Grass', 'Fomantis'), (2, '#0754', 'Grass', 'Lurantis')],
#  [(1, '#0755', 'Grass · Fairy', 'Morelull'),
#   (2, '#0756', 'Grass · Fairy', 'Shiinotic')],
#  [(1, '#0757', 'Poison · Fire', 'Salandit'),
#   (2, '#0758', 'Poison · Fire', 'Salazzle')],
#  [(1, '#0759', 'Normal · Fighting', 'Stufful'),
#   (2, '#0760', 'Normal · Fighting', 'Bewear')],
#  [(1, '#0761', 'Grass', 'Bounsweet'),
#   (2, '#0762', 'Grass', 'Steenee'),
#   (3, '#0763', 'Grass', 'Tsareena')],
#  [(1, '#0767', 'Bug · Water', 'Wimpod'),
#   (2, '#0768', 'Bug · Water', 'Golisopod')],
#  [(1, '#0769', 'Ghost · Ground', 'Sandygast'),
#   (2, '#0770', 'Ghost · Ground', 'Palossand')],
#  [(1, '#0772', 'Normal', 'Type: Null'), (2, '#0773', 'Normal', 'Silvally')],
#  [(1, '#0782', 'Dragon', 'Jangmo-o'),
#   (2, '#0783', 'Dragon · Fighting', 'Hakamo-o'),
#   (3, '#0784', 'Dragon · Fighting', 'Kommo-o')],
#  [(1, '#0789', 'Psychic', 'Cosmog'),
#   (2, '#0790', 'Psychic', 'Cosmoem'),
#   (3, '#0791', 'Psychic · Steel', 'Solgaleo'),
#   (4, '#0792', 'Psychic · Ghost', 'Lunala')],
#  [(1, '#0791', 'Psychic · Steel', 'Solgaleo')],
#  [(1, '#0792', 'Psychic · Ghost', 'Lunala')],
#  [(1, '#0803', 'Poison', 'Poipole'),
#   (2, '#0804', 'Poison · Dragon', 'Naganadel')],
#  [(1, '#0808', 'Steel', 'Meltan'), (2, '#0809', 'Steel', 'Melmetal')],
#  [(1, '#0810', 'Grass', 'Grookey'),
#   (2, '#0811', 'Grass', 'Thwackey'),
#   (3, '#0812', 'Grass', 'Rillaboom')],
#  [(1, '#0813', 'Fire', 'Scorbunny'),
#   (2, '#0814', 'Fire', 'Raboot'),
#   (3, '#0815', 'Fire', 'Cinderace')],
#  [(1, '#0816', 'Water', 'Sobble'),
#   (2, '#0817', 'Water', 'Drizzile'),
#   (3, '#0818', 'Water', 'Inteleon')],
#  [(1, '#0824', 'Bug', 'Blipbug'),
#   (2, '#0825', 'Bug · Psychic', 'Dottler'),
#   (3, '#0826', 'Bug · Psychic', 'Orbeetle')],
#  [(1, '#0821', 'Flying', 'Rookidee'),
#   (2, '#0822', 'Flying', 'Corvisquire'),
#   (3, '#0823', 'Flying · Steel', 'Corviknight')],
#  [(1, '#0819', 'Normal', 'Skwovet'), (2, '#0820', 'Normal', 'Greedent')],
#  [(1, '#0827', 'Dark', 'Nickit'), (2, '#0828', 'Dark', 'Thievul')],
#  [(1, '#0831', 'Normal', 'Wooloo'), (2, '#0832', 'Normal', 'Dubwool')],
#  [(1, '#0833', 'Water', 'Chewtle'), (2, '#0834', 'Water · Rock', 'Drednaw')],
#  [(1, '#0835', 'Electric', 'Yamper'), (2, '#0836', 'Electric', 'Boltund')],
#  [(1, '#0829', 'Grass', 'Gossifleur'), (2, '#0830', 'Grass', 'Eldegoss')],
#  [(1, '#0850', 'Fire · Bug', 'Sizzlipede'),
#   (2, '#0851', 'Fire · Bug', 'Centiskorch')],
#  [(1, '#0837', 'Rock', 'Rolycoly'),
#   (2, '#0838', 'Rock · Fire', 'Carkol'),
#   (3, '#0839', 'Rock · Fire', 'Coalossal')],
#  [(1, '#0846', 'Water', 'Arrokuda'), (2, '#0847', 'Water', 'Barraskewda')],
#  [(1, '#0868', 'Fairy', 'Milcery'), (2, '#0869', 'Fairy', 'Alcremie')],
#  [(1, '#0840', 'Grass · Dragon', 'Applin'),
#   (2, '#0841', 'Grass · Dragon', 'Flapple'),
#   (3, '#0842', 'Grass · Dragon', 'Appletun')],
#  [(1, '#0841', 'Grass · Dragon', 'Flapple')],
#  [(1, '#0842', 'Grass · Dragon', 'Appletun')],
#  [(1, '#0083', "Galarian Farfetch'd", "Farfetch'd"),
#   (2, '#0865', 'Fighting', "Sirfetch'd")],
#  [(1, '#0222', 'Galarian Corsola', 'Corsola'),
#   (2, '#0864', 'Ghost', 'Cursola')],
#  [(1, '#0859', 'Dark · Fairy', 'Impidimp'),
#   (2, '#0860', 'Dark · Fairy', 'Morgrem'),
#   (3, '#0861', 'Dark · Fairy', 'Grimmsnarl')],
#  [(1, '#0856', 'Psychic', 'Hatenna'),
#   (2, '#0857', 'Psychic', 'Hattrem'),
#   (3, '#0858', 'Psychic · Fairy', 'Hatterene')],
#  [(1, '#0878', 'Steel', 'Cufant'), (2, '#0879', 'Steel', 'Copperajah')],
#  [(1, '#0848', 'Electric · Poison', 'Toxel'),
#   (2, '#0849', 'Amped Form', 'Toxtricity'),
#   (3, '#0849', 'Low Key Form', 'Toxtricity')],
#  [(1, '#0849', 'Amped Form', 'Toxtricity')],
#  [(1, '#0849', 'Low Key Form', 'Toxtricity')],
#  [(1, '#0843', 'Ground', 'Silicobra'), (2, '#0844', 'Ground', 'Sandaconda')],
#  [(1, '#0854', 'Ghost', 'Sinistea'), (2, '#0855', 'Ghost', 'Polteageist')],
#  [(1, '#0872', 'Ice · Bug', 'Snom'), (2, '#0873', 'Ice · Bug', 'Frosmoth')],
#  [(1, '#0852', 'Fighting', 'Clobbopus'),
#   (2, '#0853', 'Fighting', 'Grapploct')],
#  [(1, '#0885', 'Dragon · Ghost', 'Dreepy'),
#   (2, '#0886', 'Dragon · Ghost', 'Drakloak'),
#   (3, '#0887', 'Dragon · Ghost', 'Dragapult')],
#  [(1, '#0891', 'Fighting', 'Kubfu'),
#   (2, '#0892', 'Single Strike Style', 'Urshifu'),
#   (3, '#0892', 'Rapid Strike Style', 'Urshifu')],
#  [(1, '#0892', 'Single Strike Style', 'Urshifu')],
#  [(1, '#0892', 'Rapid Strike Style', 'Urshifu')],
#  [(1, '#0550', 'White-Striped Form', 'Basculin'),
#   (2, '#0902', 'Male', 'Basculegion'),
#   (3, '#0902', 'Female', 'Basculegion')],
#  [(1, '#0902', 'Male', 'Basculegion')],
#  [(1, '#0902', 'Female', 'Basculegion')],
#  [(1, '#0211', 'Hisuian Qwilfish', 'Qwilfish'),
#   (2, '#0904', 'Dark · Poison', 'Overqwil')],
#  [(1, '#0906', 'Grass', 'Sprigatito'),
#   (2, '#0907', 'Grass', 'Floragato'),
#   (3, '#0908', 'Grass · Dark', 'Meowscarada')],
#  [(1, '#0909', 'Fire', 'Fuecoco'),
#   (2, '#0910', 'Fire', 'Crocalor'),
#   (3, '#0911', 'Fire · Ghost', 'Skeledirge')],
#  [(1, '#0912', 'Water', 'Quaxly'),
#   (2, '#0913', 'Water', 'Quaxwell'),
#   (3, '#0914', 'Water · Fighting', 'Quaquaval')],
#  [(1, '#0915', 'Normal', 'Lechonk'),
#   (2, '#0916', 'Male', 'Oinkologne'),
#   (3, '#0916', 'Female', 'Oinkologne')],
#  [(1, '#0916', 'Male', 'Oinkologne')],
#  [(1, '#0916', 'Female', 'Oinkologne')],
#  [(1, '#0917', 'Bug', 'Tarountula'), (2, '#0918', 'Bug', 'Spidops')],
#  [(1, '#0919', 'Bug', 'Nymble'), (2, '#0920', 'Bug · Dark', 'Lokix')],
#  [(1, '#0953', 'Bug', 'Rellor'), (2, '#0954', 'Bug · Psychic', 'Rabsca')],
#  [(1, '#0971', 'Ghost', 'Greavard'), (2, '#0972', 'Ghost', 'Houndstone')],
#  [(1, '#0955', 'Psychic', 'Flittle'), (2, '#0956', 'Psychic', 'Espathra')],
#  [(1, '#0960', 'Water', 'Wiglett'), (2, '#0961', 'Water', 'Wugtrio')],
#  [(1, '#0963', 'Water', 'Finizen'), (2, '#0964', 'Zero Form', 'Palafin')],
#  [(1, '#0928', 'Grass · Normal', 'Smoliv'),
#   (2, '#0929', 'Grass · Normal', 'Dolliv'),
#   (3, '#0930', 'Grass · Normal', 'Arboliva')],
#  [(1, '#0951', 'Grass', 'Capsakid'),
#   (2, '#0952', 'Grass · Fire', 'Scovillain')],
#  [(1, '#0938', 'Electric', 'Tadbulb'), (2, '#0939', 'Electric', 'Bellibolt')],
#  [(1, '#0965', 'Steel · Poison', 'Varoom'),
#   (2, '#0966', 'Steel · Poison', 'Revavroom')],
#  [(1, '#0924', 'Normal', 'Tandemaus'),
#   (2, '#0925', 'Family of Three', 'Maushold'),
#   (3, '#0925', 'Family of Four', 'Maushold')],
#  [(1, '#0925', 'Family of Three', 'Maushold')],
#  [(1, '#0925', 'Family of Four', 'Maushold')],
#  [(1, '#0974', 'Ice', 'Cetoddle'), (2, '#0975', 'Ice', 'Cetitan')],
#  [(1, '#0996', 'Dragon · Ice', 'Frigibax'),
#   (2, '#0997', 'Dragon · Ice', 'Arctibax'),
#   (3, '#0998', 'Dragon · Ice', 'Baxcalibur')],
#  [(1, '#0921', 'Electric', 'Pawmi'),
#   (2, '#0922', 'Electric · Fighting', 'Pawmo'),
#   (3, '#0923', 'Electric · Fighting', 'Pawmot')],
#  [(1, '#0940', 'Electric · Flying', 'Wattrel'),
#   (2, '#0941', 'Electric · Flying', 'Kilowattrel')],
#  [(1, '#0932', 'Rock', 'Nacli'),
#   (2, '#0933', 'Rock', 'Naclstack'),
#   (3, '#0934', 'Rock', 'Garganacl')],
#  [(1, '#0969', 'Rock · Poison', 'Glimmet'),
#   (2, '#0970', 'Rock · Poison', 'Glimmora')],
#  [(1, '#0944', 'Poison · Normal', 'Shroodle'),
#   (2, '#0945', 'Poison · Normal', 'Grafaiai')],
#  [(1, '#0926', 'Fairy', 'Fidough'), (2, '#0927', 'Fairy', 'Dachsbun')],
#  [(1, '#0942', 'Dark', 'Maschiff'), (2, '#0943', 'Dark', 'Mabosstiff')],
#  [(1, '#0946', 'Grass · Ghost', 'Bramblin'),
#   (2, '#0947', 'Grass · Ghost', 'Brambleghast')],
#  [(1, '#0999', 'Chest Form', 'Gimmighoul'),
#   (2, '#1000', 'Steel · Ghost', 'Gholdengo')],
#  [(1, '#0957', 'Fairy · Steel', 'Tinkatink'),
#   (2, '#0958', 'Fairy · Steel', 'Tinkatuff'),
#   (3, '#0959', 'Fairy · Steel', 'Tinkaton')],
#  [(1, '#0935', 'Fire', 'Charcadet'),
#   (2, '#0936', 'Fire · Psychic', 'Armarouge'),
#   (3, '#0937', 'Fire · Ghost', 'Ceruledge')],
#  [(1, '#0936', 'Fire · Psychic', 'Armarouge')],
#  [(1, '#0937', 'Fire · Ghost', 'Ceruledge')],
#  [(1, '#0948', 'Ground · Grass', 'Toedscool'),
#   (2, '#0949', 'Ground · Grass', 'Toedscruel')]]

# %%
#Remueve todos los pokemon que son mayores a la generacion 2 (N > 251) 
step_2 = [ [elem for elem in branch_list if int(elem[1][1:]) <= 251] for branch_list in raw ] 

step_2
# Out:
# [[(1, '#0001', 'Grass · Poison', 'Bulbasaur'),
#   (2, '#0002', 'Grass · Poison', 'Ivysaur'),
#   (3, '#0003', 'Grass · Poison', 'Venusaur')],
#  [(1, '#0004', 'Fire', 'Charmander'),
#   (2, '#0005', 'Fire', 'Charmeleon'),
#   (3, '#0006', 'Fire · Flying', 'Charizard')],
#  [(1, '#0007', 'Water', 'Squirtle'),
#   (2, '#0008', 'Water', 'Wartortle'),
#   (3, '#0009', 'Water', 'Blastoise')],
#  [(1, '#0010', 'Bug', 'Caterpie'),
#   (2, '#0011', 'Bug', 'Metapod'),
#   (3, '#0012', 'Bug · Flying', 'Butterfree')],
#  [(1, '#0013', 'Bug · Poison', 'Weedle'),
#   (2, '#0014', 'Bug · Poison', 'Kakuna'),
#   (3, '#0015', 'Bug · Poison', 'Beedrill')],
#  [(1, '#0016', 'Normal · Flying', 'Pidgey'),
#   (2, '#0017', 'Normal · Flying', 'Pidgeotto'),
#   (3, '#0018', 'Normal · Flying', 'Pidgeot')],
#  [(1, '#0019', 'Normal', 'Rattata'), (2, '#0020', 'Normal', 'Raticate')],
#  [(1, '#0019', 'Alolan Rattata', 'Rattata'),
#   (2, '#0020', 'Alolan Raticate', 'Raticate')],
#  [(1, '#0021', 'Normal · Flying', 'Spearow'),
#   (2, '#0022', 'Normal · Flying', 'Fearow')],
#  [(1, '#0023', 'Poison', 'Ekans'), (2, '#0024', 'Poison', 'Arbok')],
#  [(1, '#0172', 'Electric', 'Pichu'),
#   (2, '#0025', 'Electric', 'Pikachu'),
#   (3, '#0026', 'Electric', 'Raichu'),
#   (4, '#0026', 'Alolan Raichu', 'Raichu')],
#  [(1, '#0026', 'Electric', 'Raichu')],
#  [(1, '#0026', 'Alolan Raichu', 'Raichu')],
#  [(1, '#0027', 'Ground', 'Sandshrew'), (2, '#0028', 'Ground', 'Sandslash')],
#  [(1, '#0027', 'Alolan Sandshrew', 'Sandshrew'),
#   (2, '#0028', 'Alolan Sandslash', 'Sandslash')],
#  [(1, '#0029', 'Poison', 'Nidoran♀'),
#   (2, '#0030', 'Poison', 'Nidorina'),
#   (3, '#0031', 'Poison · Ground', 'Nidoqueen')],
#  [(1, '#0032', 'Poison', 'Nidoran♂'),
#   (2, '#0033', 'Poison', 'Nidorino'),
#   (3, '#0034', 'Poison · Ground', 'Nidoking')],
#  [(1, '#0173', 'Fairy', 'Cleffa'),
#   (2, '#0035', 'Fairy', 'Clefairy'),
#   (3, '#0036', 'Fairy', 'Clefable')],
#  [(1, '#0037', 'Fire', 'Vulpix'), (2, '#0038', 'Fire', 'Ninetales')],
#  [(1, '#0037', 'Alolan Vulpix', 'Vulpix'),
#   (2, '#0038', 'Alolan Ninetales', 'Ninetales')],
#  [(1, '#0174', 'Normal · Fairy', 'Igglybuff'),
#   (2, '#0039', 'Normal · Fairy', 'Jigglypuff'),
#   (3, '#0040', 'Normal · Fairy', 'Wigglytuff')],
#  [(1, '#0041', 'Poison · Flying', 'Zubat'),
#   (2, '#0042', 'Poison · Flying', 'Golbat'),
#   (3, '#0169', 'Poison · Flying', 'Crobat')],
#  [(1, '#0043', 'Grass · Poison', 'Oddish'),
#   (2, '#0044', 'Grass · Poison', 'Gloom'),
#   (3, '#0045', 'Grass · Poison', 'Vileplume'),
#   (4, '#0182', 'Grass', 'Bellossom')],
#  [(1, '#0045', 'Grass · Poison', 'Vileplume')],
#  [(1, '#0182', 'Grass', 'Bellossom')],
#  [(1, '#0046', 'Bug · Grass', 'Paras'),
#   (2, '#0047', 'Bug · Grass', 'Parasect')],
#  [(1, '#0048', 'Bug · Poison', 'Venonat'),
#   (2, '#0049', 'Bug · Poison', 'Venomoth')],
#  [(1, '#0050', 'Ground', 'Diglett'), (2, '#0051', 'Ground', 'Dugtrio')],
#  [(1, '#0050', 'Alolan Diglett', 'Diglett'),
#   (2, '#0051', 'Alolan Dugtrio', 'Dugtrio')],
#  [(1, '#0052', 'Normal', 'Meowth'), (2, '#0053', 'Normal', 'Persian')],
#  [(1, '#0052', 'Alolan Meowth', 'Meowth'),
#   (2, '#0053', 'Alolan Persian', 'Persian')],
#  [(1, '#0052', 'Galarian Meowth', 'Meowth')],
#  [(1, '#0054', 'Water', 'Psyduck'), (2, '#0055', 'Water', 'Golduck')],
#  [(1, '#0056', 'Fighting', 'Mankey'), (2, '#0057', 'Fighting', 'Primeape')],
#  [(1, '#0058', 'Fire', 'Growlithe'), (2, '#0059', 'Fire', 'Arcanine')],
#  [(1, '#0058', 'Hisuian Growlithe', 'Growlithe'),
#   (2, '#0059', 'Hisuian Arcanine', 'Arcanine')],
#  [(1, '#0060', 'Water', 'Poliwag'),
#   (2, '#0061', 'Water', 'Poliwhirl'),
#   (3, '#0062', 'Water · Fighting', 'Poliwrath'),
#   (4, '#0186', 'Water', 'Politoed')],
#  [(1, '#0062', 'Water · Fighting', 'Poliwrath')],
#  [(1, '#0186', 'Water', 'Politoed')],
#  [(1, '#0063', 'Psychic', 'Abra'),
#   (2, '#0064', 'Psychic', 'Kadabra'),
#   (3, '#0065', 'Psychic', 'Alakazam')],
#  [(1, '#0066', 'Fighting', 'Machop'),
#   (2, '#0067', 'Fighting', 'Machoke'),
#   (3, '#0068', 'Fighting', 'Machamp')],
#  [(1, '#0069', 'Grass · Poison', 'Bellsprout'),
#   (2, '#0070', 'Grass · Poison', 'Weepinbell'),
#   (3, '#0071', 'Grass · Poison', 'Victreebel')],
#  [(1, '#0072', 'Water · Poison', 'Tentacool'),
#   (2, '#0073', 'Water · Poison', 'Tentacruel')],
#  [(1, '#0074', 'Rock · Ground', 'Geodude'),
#   (2, '#0075', 'Rock · Ground', 'Graveler'),
#   (3, '#0076', 'Rock · Ground', 'Golem')],
#  [(1, '#0074', 'Alolan Geodude', 'Geodude'),
#   (2, '#0075', 'Alolan Graveler', 'Graveler'),
#   (3, '#0076', 'Alolan Golem', 'Golem')],
#  [(1, '#0077', 'Fire', 'Ponyta'), (2, '#0078', 'Fire', 'Rapidash')],
#  [(1, '#0077', 'Galarian Ponyta', 'Ponyta'),
#   (2, '#0078', 'Galarian Rapidash', 'Rapidash')],
#  [(1, '#0079', 'Water · Psychic', 'Slowpoke'),
#   (2, '#0080', 'Water · Psychic', 'Slowbro'),
#   (3, '#0199', 'Water · Psychic', 'Slowking')],
#  [(1, '#0080', 'Water · Psychic', 'Slowbro')],
#  [(1, '#0199', 'Water · Psychic', 'Slowking')],
#  [(1, '#0079', 'Galarian Slowpoke', 'Slowpoke'),
#   (2, '#0080', 'Galarian Slowbro', 'Slowbro'),
#   (3, '#0199', 'Galarian Slowking', 'Slowking')],
#  [(1, '#0080', 'Galarian Slowbro', 'Slowbro')],
#  [(1, '#0199', 'Galarian Slowking', 'Slowking')],
#  [(1, '#0081', 'Electric · Steel', 'Magnemite'),
#   (2, '#0082', 'Electric · Steel', 'Magneton')],
#  [(1, '#0084', 'Normal · Flying', 'Doduo'),
#   (2, '#0085', 'Normal · Flying', 'Dodrio')],
#  [(1, '#0086', 'Water', 'Seel'), (2, '#0087', 'Water · Ice', 'Dewgong')],
#  [(1, '#0088', 'Poison', 'Grimer'), (2, '#0089', 'Poison', 'Muk')],
#  [(1, '#0088', 'Alolan Grimer', 'Grimer'), (2, '#0089', 'Alolan Muk', 'Muk')],
#  [(1, '#0090', 'Water', 'Shellder'), (2, '#0091', 'Water · Ice', 'Cloyster')],
#  [(1, '#0092', 'Ghost · Poison', 'Gastly'),
#   (2, '#0093', 'Ghost · Poison', 'Haunter'),
#   (3, '#0094', 'Ghost · Poison', 'Gengar')],
#  [(1, '#0095', 'Rock · Ground', 'Onix'),
#   (2, '#0208', 'Steel · Ground', 'Steelix')],
#  [(1, '#0096', 'Psychic', 'Drowzee'), (2, '#0097', 'Psychic', 'Hypno')],
#  [(1, '#0098', 'Water', 'Krabby'), (2, '#0099', 'Water', 'Kingler')],
#  [(1, '#0100', 'Electric', 'Voltorb'), (2, '#0101', 'Electric', 'Electrode')],
#  [(1, '#0100', 'Hisuian Voltorb', 'Voltorb'),
#   (2, '#0101', 'Hisuian Electrode', 'Electrode')],
#  [(1, '#0102', 'Grass · Psychic', 'Exeggcute'),
#   (2, '#0103', 'Grass · Psychic', 'Exeggutor'),
#   (3, '#0103', 'Alolan Exeggutor', 'Exeggutor')],
#  [(1, '#0103', 'Grass · Psychic', 'Exeggutor')],
#  [(1, '#0103', 'Alolan Exeggutor', 'Exeggutor')],
#  [(1, '#0104', 'Ground', 'Cubone'),
#   (2, '#0105', 'Ground', 'Marowak'),
#   (3, '#0105', 'Alolan Marowak', 'Marowak')],
#  [(1, '#0105', 'Ground', 'Marowak')],
#  [(1, '#0105', 'Alolan Marowak', 'Marowak')],
#  [(1, '#0236', 'Fighting', 'Tyrogue'),
#   (2, '#0106', 'Fighting', 'Hitmonlee'),
#   (3, '#0107', 'Fighting', 'Hitmonchan'),
#   (4, '#0237', 'Fighting', 'Hitmontop')],
#  [(1, '#0106', 'Fighting', 'Hitmonlee')],
#  [(1, '#0107', 'Fighting', 'Hitmonchan')],
#  [(1, '#0237', 'Fighting', 'Hitmontop')],
#  [(1, '#0108', 'Normal', 'Lickitung')],
#  [(1, '#0109', 'Poison', 'Koffing'),
#   (2, '#0110', 'Poison', 'Weezing'),
#   (3, '#0110', 'Galarian Weezing', 'Weezing')],
#  [(1, '#0110', 'Poison', 'Weezing')],
#  [(1, '#0110', 'Galarian Weezing', 'Weezing')],
#  [(1, '#0111', 'Ground · Rock', 'Rhyhorn'),
#   (2, '#0112', 'Ground · Rock', 'Rhydon')],
#  [(2, '#0113', 'Normal', 'Chansey'), (3, '#0242', 'Normal', 'Blissey')],
#  [(1, '#0114', 'Grass', 'Tangela')],
#  [(1, '#0116', 'Water', 'Horsea'),
#   (2, '#0117', 'Water', 'Seadra'),
#   (3, '#0230', 'Water · Dragon', 'Kingdra')],
#  [(1, '#0118', 'Water', 'Goldeen'), (2, '#0119', 'Water', 'Seaking')],
#  [(1, '#0120', 'Water', 'Staryu'), (2, '#0121', 'Water · Psychic', 'Starmie')],
#  [(2, '#0122', 'Psychic · Fairy', 'Mr. Mime'),
#   (3, '#0122', 'Galarian Mr. Mime', 'Mr. Mime')],
#  [(1, '#0122', 'Psychic · Fairy', 'Mr. Mime')],
#  [(1, '#0122', 'Galarian Mr. Mime', 'Mr. Mime')],
#  [(1, '#0123', 'Bug · Flying', 'Scyther'),
#   (2, '#0212', 'Bug · Steel', 'Scizor')],
#  [(1, '#0212', 'Bug · Steel', 'Scizor')],
#  [],
#  [(1, '#0238', 'Ice · Psychic', 'Smoochum'),
#   (2, '#0124', 'Ice · Psychic', 'Jynx')],
#  [(1, '#0239', 'Electric', 'Elekid'), (2, '#0125', 'Electric', 'Electabuzz')],
#  [(1, '#0240', 'Fire', 'Magby'), (2, '#0126', 'Fire', 'Magmar')],
#  [(1, '#0129', 'Water', 'Magikarp'),
#   (2, '#0130', 'Water · Flying', 'Gyarados')],
#  [(1, '#0133', 'Normal', 'Eevee'),
#   (2, '#0134', 'Water', 'Vaporeon'),
#   (3, '#0135', 'Electric', 'Jolteon'),
#   (4, '#0136', 'Fire', 'Flareon')],
#  [(1, '#0134', 'Water', 'Vaporeon')],
#  [(1, '#0135', 'Electric', 'Jolteon')],
#  [(1, '#0136', 'Fire', 'Flareon')],
#  [(1, '#0133', 'Normal', 'Eevee'),
#   (2, '#0196', 'Psychic', 'Espeon'),
#   (3, '#0197', 'Dark', 'Umbreon')],
#  [(1, '#0196', 'Psychic', 'Espeon')],
#  [(1, '#0197', 'Dark', 'Umbreon')],
#  [(1, '#0133', 'Normal', 'Eevee')],
#  [],
#  [],
#  [(1, '#0133', 'Normal', 'Eevee')],
#  [(1, '#0137', 'Normal', 'Porygon'), (2, '#0233', 'Normal', 'Porygon2')],
#  [(1, '#0138', 'Rock · Water', 'Omanyte'),
#   (2, '#0139', 'Rock · Water', 'Omastar')],
#  [(1, '#0140', 'Rock · Water', 'Kabuto'),
#   (2, '#0141', 'Rock · Water', 'Kabutops')],
#  [(2, '#0143', 'Normal', 'Snorlax')],
#  [(1, '#0147', 'Dragon', 'Dratini'),
#   (2, '#0148', 'Dragon', 'Dragonair'),
#   (3, '#0149', 'Dragon · Flying', 'Dragonite')],
#  [(1, '#0152', 'Grass', 'Chikorita'),
#   (2, '#0153', 'Grass', 'Bayleef'),
#   (3, '#0154', 'Grass', 'Meganium')],
#  [(1, '#0155', 'Fire', 'Cyndaquil'),
#   (2, '#0156', 'Fire', 'Quilava'),
#   (3, '#0157', 'Fire', 'Typhlosion'),
#   (4, '#0157', 'Hisuian Typhlosion', 'Typhlosion')],
#  [(1, '#0157', 'Fire', 'Typhlosion')],
#  [(1, '#0157', 'Hisuian Typhlosion', 'Typhlosion')],
#  [(1, '#0158', 'Water', 'Totodile'),
#   (2, '#0159', 'Water', 'Croconaw'),
#   (3, '#0160', 'Water', 'Feraligatr')],
#  [(1, '#0161', 'Normal', 'Sentret'), (2, '#0162', 'Normal', 'Furret')],
#  [(1, '#0163', 'Normal · Flying', 'Hoothoot'),
#   (2, '#0164', 'Normal · Flying', 'Noctowl')],
#  [(1, '#0165', 'Bug · Flying', 'Ledyba'),
#   (2, '#0166', 'Bug · Flying', 'Ledian')],
#  [(1, '#0167', 'Bug · Poison', 'Spinarak'),
#   (2, '#0168', 'Bug · Poison', 'Ariados')],
#  [(1, '#0170', 'Water · Electric', 'Chinchou'),
#   (2, '#0171', 'Water · Electric', 'Lanturn')],
#  [(1, '#0175', 'Fairy', 'Togepi'), (2, '#0176', 'Fairy · Flying', 'Togetic')],
#  [(1, '#0177', 'Psychic · Flying', 'Natu'),
#   (2, '#0178', 'Psychic · Flying', 'Xatu')],
#  [(1, '#0179', 'Electric', 'Mareep'),
#   (2, '#0180', 'Electric', 'Flaaffy'),
#   (3, '#0181', 'Electric', 'Ampharos')],
#  [(2, '#0183', 'Water · Fairy', 'Marill'),
#   (3, '#0184', 'Water · Fairy', 'Azumarill')],
#  [(2, '#0185', 'Rock', 'Sudowoodo')],
#  [(1, '#0187', 'Grass · Flying', 'Hoppip'),
#   (2, '#0188', 'Grass · Flying', 'Skiploom'),
#   (3, '#0189', 'Grass · Flying', 'Jumpluff')],
#  [(1, '#0190', 'Normal', 'Aipom')],
#  [(1, '#0191', 'Grass', 'Sunkern'), (2, '#0192', 'Grass', 'Sunflora')],
#  [(1, '#0193', 'Bug · Flying', 'Yanma')],
#  [(1, '#0194', 'Water · Ground', 'Wooper'),
#   (2, '#0195', 'Water · Ground', 'Quagsire')],
#  [(1, '#0194', 'Paldean Wooper', 'Wooper')],
#  [(1, '#0198', 'Dark · Flying', 'Murkrow')],
#  [(1, '#0200', 'Ghost', 'Misdreavus')],
#  [(2, '#0202', 'Psychic', 'Wobbuffet')],
#  [(1, '#0204', 'Bug', 'Pineco'), (2, '#0205', 'Bug · Steel', 'Forretress')],
#  [(1, '#0207', 'Ground · Flying', 'Gligar')],
#  [(1, '#0209', 'Fairy', 'Snubbull'), (2, '#0210', 'Fairy', 'Granbull')],
#  [(1, '#0215', 'Dark · Ice', 'Sneasel')],
#  [(1, '#0215', 'Hisuian Sneasel', 'Sneasel')],
#  [(1, '#0216', 'Normal', 'Teddiursa'), (2, '#0217', 'Normal', 'Ursaring')],
#  [(1, '#0218', 'Fire', 'Slugma'), (2, '#0219', 'Fire · Rock', 'Magcargo')],
#  [(1, '#0220', 'Ice · Ground', 'Swinub'),
#   (2, '#0221', 'Ice · Ground', 'Piloswine')],
#  [(1, '#0223', 'Water', 'Remoraid'), (2, '#0224', 'Water', 'Octillery')],
#  [(2, '#0226', 'Water · Flying', 'Mantine')],
#  [(1, '#0228', 'Dark · Fire', 'Houndour'),
#   (2, '#0229', 'Dark · Fire', 'Houndoom')],
#  [(1, '#0231', 'Ground', 'Phanpy'), (2, '#0232', 'Ground', 'Donphan')],
#  [(1, '#0246', 'Rock · Ground', 'Larvitar'),
#   (2, '#0247', 'Rock · Ground', 'Pupitar'),
#   (3, '#0248', 'Rock · Dark', 'Tyranitar')],
#  [(1, '#0234', 'Normal', 'Stantler')],
#  [(1, '#0203', 'Normal · Psychic', 'Girafarig')],
#  [(1, '#0206', 'Normal', 'Dunsparce')],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [(1, '#0083', "Galarian Farfetch'd", "Farfetch'd")],
#  [(1, '#0222', 'Galarian Corsola', 'Corsola')],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [(1, '#0211', 'Hisuian Qwilfish', 'Qwilfish')],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %%
#Remuever las entradas que no tengan información de step_2, las entradas que necesitamos son 
#mayores a 1, tomando el tamaño len() de cada elemento examinado.
step_3 = [<#completar> in <#completar> if len(elem) > 1]

# %%
#Remuever las entradas que no tengan información de step_2, las entradas que necesitamos son 
#mayores a 1, tomando el tamaño len() de cada elemento examinado.

step_1 = [[elem for elem in branch_list if 'Alol' not in elem[2]] for branch_list in raw]
step_2 = [ [elem for elem in branch_list if int(elem[1][1:]) <= 251] for branch_list in step_2 ] 
step_3 = [elem for elem in step_2 if len(elem) > 1] 
step_3
# Out:
# [[(1, '#0001', 'Grass · Poison', 'Bulbasaur'),
#   (2, '#0002', 'Grass · Poison', 'Ivysaur'),
#   (3, '#0003', 'Grass · Poison', 'Venusaur')],
#  [(1, '#0004', 'Fire', 'Charmander'),
#   (2, '#0005', 'Fire', 'Charmeleon'),
#   (3, '#0006', 'Fire · Flying', 'Charizard')],
#  [(1, '#0007', 'Water', 'Squirtle'),
#   (2, '#0008', 'Water', 'Wartortle'),
#   (3, '#0009', 'Water', 'Blastoise')],
#  [(1, '#0010', 'Bug', 'Caterpie'),
#   (2, '#0011', 'Bug', 'Metapod'),
#   (3, '#0012', 'Bug · Flying', 'Butterfree')],
#  [(1, '#0013', 'Bug · Poison', 'Weedle'),
#   (2, '#0014', 'Bug · Poison', 'Kakuna'),
#   (3, '#0015', 'Bug · Poison', 'Beedrill')],
#  [(1, '#0016', 'Normal · Flying', 'Pidgey'),
#   (2, '#0017', 'Normal · Flying', 'Pidgeotto'),
#   (3, '#0018', 'Normal · Flying', 'Pidgeot')],
#  [(1, '#0019', 'Normal', 'Rattata'), (2, '#0020', 'Normal', 'Raticate')],
#  [(1, '#0019', 'Alolan Rattata', 'Rattata'),
#   (2, '#0020', 'Alolan Raticate', 'Raticate')],
#  [(1, '#0021', 'Normal · Flying', 'Spearow'),
#   (2, '#0022', 'Normal · Flying', 'Fearow')],
#  [(1, '#0023', 'Poison', 'Ekans'), (2, '#0024', 'Poison', 'Arbok')],
#  [(1, '#0172', 'Electric', 'Pichu'),
#   (2, '#0025', 'Electric', 'Pikachu'),
#   (3, '#0026', 'Electric', 'Raichu'),
#   (4, '#0026', 'Alolan Raichu', 'Raichu')],
#  [(1, '#0027', 'Ground', 'Sandshrew'), (2, '#0028', 'Ground', 'Sandslash')],
#  [(1, '#0027', 'Alolan Sandshrew', 'Sandshrew'),
#   (2, '#0028', 'Alolan Sandslash', 'Sandslash')],
#  [(1, '#0029', 'Poison', 'Nidoran♀'),
#   (2, '#0030', 'Poison', 'Nidorina'),
#   (3, '#0031', 'Poison · Ground', 'Nidoqueen')],
#  [(1, '#0032', 'Poison', 'Nidoran♂'),
#   (2, '#0033', 'Poison', 'Nidorino'),
#   (3, '#0034', 'Poison · Ground', 'Nidoking')],
#  [(1, '#0173', 'Fairy', 'Cleffa'),
#   (2, '#0035', 'Fairy', 'Clefairy'),
#   (3, '#0036', 'Fairy', 'Clefable')],
#  [(1, '#0037', 'Fire', 'Vulpix'), (2, '#0038', 'Fire', 'Ninetales')],
#  [(1, '#0037', 'Alolan Vulpix', 'Vulpix'),
#   (2, '#0038', 'Alolan Ninetales', 'Ninetales')],
#  [(1, '#0174', 'Normal · Fairy', 'Igglybuff'),
#   (2, '#0039', 'Normal · Fairy', 'Jigglypuff'),
#   (3, '#0040', 'Normal · Fairy', 'Wigglytuff')],
#  [(1, '#0041', 'Poison · Flying', 'Zubat'),
#   (2, '#0042', 'Poison · Flying', 'Golbat'),
#   (3, '#0169', 'Poison · Flying', 'Crobat')],
#  [(1, '#0043', 'Grass · Poison', 'Oddish'),
#   (2, '#0044', 'Grass · Poison', 'Gloom'),
#   (3, '#0045', 'Grass · Poison', 'Vileplume'),
#   (4, '#0182', 'Grass', 'Bellossom')],
#  [(1, '#0046', 'Bug · Grass', 'Paras'),
#   (2, '#0047', 'Bug · Grass', 'Parasect')],
#  [(1, '#0048', 'Bug · Poison', 'Venonat'),
#   (2, '#0049', 'Bug · Poison', 'Venomoth')],
#  [(1, '#0050', 'Ground', 'Diglett'), (2, '#0051', 'Ground', 'Dugtrio')],
#  [(1, '#0050', 'Alolan Diglett', 'Diglett'),
#   (2, '#0051', 'Alolan Dugtrio', 'Dugtrio')],
#  [(1, '#0052', 'Normal', 'Meowth'), (2, '#0053', 'Normal', 'Persian')],
#  [(1, '#0052', 'Alolan Meowth', 'Meowth'),
#   (2, '#0053', 'Alolan Persian', 'Persian')],
#  [(1, '#0054', 'Water', 'Psyduck'), (2, '#0055', 'Water', 'Golduck')],
#  [(1, '#0056', 'Fighting', 'Mankey'), (2, '#0057', 'Fighting', 'Primeape')],
#  [(1, '#0058', 'Fire', 'Growlithe'), (2, '#0059', 'Fire', 'Arcanine')],
#  [(1, '#0058', 'Hisuian Growlithe', 'Growlithe'),
#   (2, '#0059', 'Hisuian Arcanine', 'Arcanine')],
#  [(1, '#0060', 'Water', 'Poliwag'),
#   (2, '#0061', 'Water', 'Poliwhirl'),
#   (3, '#0062', 'Water · Fighting', 'Poliwrath'),
#   (4, '#0186', 'Water', 'Politoed')],
#  [(1, '#0063', 'Psychic', 'Abra'),
#   (2, '#0064', 'Psychic', 'Kadabra'),
#   (3, '#0065', 'Psychic', 'Alakazam')],
#  [(1, '#0066', 'Fighting', 'Machop'),
#   (2, '#0067', 'Fighting', 'Machoke'),
#   (3, '#0068', 'Fighting', 'Machamp')],
#  [(1, '#0069', 'Grass · Poison', 'Bellsprout'),
#   (2, '#0070', 'Grass · Poison', 'Weepinbell'),
#   (3, '#0071', 'Grass · Poison', 'Victreebel')],
#  [(1, '#0072', 'Water · Poison', 'Tentacool'),
#   (2, '#0073', 'Water · Poison', 'Tentacruel')],
#  [(1, '#0074', 'Rock · Ground', 'Geodude'),
#   (2, '#0075', 'Rock · Ground', 'Graveler'),
#   (3, '#0076', 'Rock · Ground', 'Golem')],
#  [(1, '#0074', 'Alolan Geodude', 'Geodude'),
#   (2, '#0075', 'Alolan Graveler', 'Graveler'),
#   (3, '#0076', 'Alolan Golem', 'Golem')],
#  [(1, '#0077', 'Fire', 'Ponyta'), (2, '#0078', 'Fire', 'Rapidash')],
#  [(1, '#0077', 'Galarian Ponyta', 'Ponyta'),
#   (2, '#0078', 'Galarian Rapidash', 'Rapidash')],
#  [(1, '#0079', 'Water · Psychic', 'Slowpoke'),
#   (2, '#0080', 'Water · Psychic', 'Slowbro'),
#   (3, '#0199', 'Water · Psychic', 'Slowking')],
#  [(1, '#0079', 'Galarian Slowpoke', 'Slowpoke'),
#   (2, '#0080', 'Galarian Slowbro', 'Slowbro'),
#   (3, '#0199', 'Galarian Slowking', 'Slowking')],
#  [(1, '#0081', 'Electric · Steel', 'Magnemite'),
#   (2, '#0082', 'Electric · Steel', 'Magneton')],
#  [(1, '#0084', 'Normal · Flying', 'Doduo'),
#   (2, '#0085', 'Normal · Flying', 'Dodrio')],
#  [(1, '#0086', 'Water', 'Seel'), (2, '#0087', 'Water · Ice', 'Dewgong')],
#  [(1, '#0088', 'Poison', 'Grimer'), (2, '#0089', 'Poison', 'Muk')],
#  [(1, '#0088', 'Alolan Grimer', 'Grimer'), (2, '#0089', 'Alolan Muk', 'Muk')],
#  [(1, '#0090', 'Water', 'Shellder'), (2, '#0091', 'Water · Ice', 'Cloyster')],
#  [(1, '#0092', 'Ghost · Poison', 'Gastly'),
#   (2, '#0093', 'Ghost · Poison', 'Haunter'),
#   (3, '#0094', 'Ghost · Poison', 'Gengar')],
#  [(1, '#0095', 'Rock · Ground', 'Onix'),
#   (2, '#0208', 'Steel · Ground', 'Steelix')],
#  [(1, '#0096', 'Psychic', 'Drowzee'), (2, '#0097', 'Psychic', 'Hypno')],
#  [(1, '#0098', 'Water', 'Krabby'), (2, '#0099', 'Water', 'Kingler')],
#  [(1, '#0100', 'Electric', 'Voltorb'), (2, '#0101', 'Electric', 'Electrode')],
#  [(1, '#0100', 'Hisuian Voltorb', 'Voltorb'),
#   (2, '#0101', 'Hisuian Electrode', 'Electrode')],
#  [(1, '#0102', 'Grass · Psychic', 'Exeggcute'),
#   (2, '#0103', 'Grass · Psychic', 'Exeggutor'),
#   (3, '#0103', 'Alolan Exeggutor', 'Exeggutor')],
#  [(1, '#0104', 'Ground', 'Cubone'),
#   (2, '#0105', 'Ground', 'Marowak'),
#   (3, '#0105', 'Alolan Marowak', 'Marowak')],
#  [(1, '#0236', 'Fighting', 'Tyrogue'),
#   (2, '#0106', 'Fighting', 'Hitmonlee'),
#   (3, '#0107', 'Fighting', 'Hitmonchan'),
#   (4, '#0237', 'Fighting', 'Hitmontop')],
#  [(1, '#0109', 'Poison', 'Koffing'),
#   (2, '#0110', 'Poison', 'Weezing'),
#   (3, '#0110', 'Galarian Weezing', 'Weezing')],
#  [(1, '#0111', 'Ground · Rock', 'Rhyhorn'),
#   (2, '#0112', 'Ground · Rock', 'Rhydon')],
#  [(2, '#0113', 'Normal', 'Chansey'), (3, '#0242', 'Normal', 'Blissey')],
#  [(1, '#0116', 'Water', 'Horsea'),
#   (2, '#0117', 'Water', 'Seadra'),
#   (3, '#0230', 'Water · Dragon', 'Kingdra')],
#  [(1, '#0118', 'Water', 'Goldeen'), (2, '#0119', 'Water', 'Seaking')],
#  [(1, '#0120', 'Water', 'Staryu'), (2, '#0121', 'Water · Psychic', 'Starmie')],
#  [(2, '#0122', 'Psychic · Fairy', 'Mr. Mime'),
#   (3, '#0122', 'Galarian Mr. Mime', 'Mr. Mime')],
#  [(1, '#0123', 'Bug · Flying', 'Scyther'),
#   (2, '#0212', 'Bug · Steel', 'Scizor')],
#  [(1, '#0238', 'Ice · Psychic', 'Smoochum'),
#   (2, '#0124', 'Ice · Psychic', 'Jynx')],
#  [(1, '#0239', 'Electric', 'Elekid'), (2, '#0125', 'Electric', 'Electabuzz')],
#  [(1, '#0240', 'Fire', 'Magby'), (2, '#0126', 'Fire', 'Magmar')],
#  [(1, '#0129', 'Water', 'Magikarp'),
#   (2, '#0130', 'Water · Flying', 'Gyarados')],
#  [(1, '#0133', 'Normal', 'Eevee'),
#   (2, '#0134', 'Water', 'Vaporeon'),
#   (3, '#0135', 'Electric', 'Jolteon'),
#   (4, '#0136', 'Fire', 'Flareon')],
#  [(1, '#0133', 'Normal', 'Eevee'),
#   (2, '#0196', 'Psychic', 'Espeon'),
#   (3, '#0197', 'Dark', 'Umbreon')],
#  [(1, '#0137', 'Normal', 'Porygon'), (2, '#0233', 'Normal', 'Porygon2')],
#  [(1, '#0138', 'Rock · Water', 'Omanyte'),
#   (2, '#0139', 'Rock · Water', 'Omastar')],
#  [(1, '#0140', 'Rock · Water', 'Kabuto'),
#   (2, '#0141', 'Rock · Water', 'Kabutops')],
#  [(1, '#0147', 'Dragon', 'Dratini'),
#   (2, '#0148', 'Dragon', 'Dragonair'),
#   (3, '#0149', 'Dragon · Flying', 'Dragonite')],
#  [(1, '#0152', 'Grass', 'Chikorita'),
#   (2, '#0153', 'Grass', 'Bayleef'),
#   (3, '#0154', 'Grass', 'Meganium')],
#  [(1, '#0155', 'Fire', 'Cyndaquil'),
#   (2, '#0156', 'Fire', 'Quilava'),
#   (3, '#0157', 'Fire', 'Typhlosion'),
#   (4, '#0157', 'Hisuian Typhlosion', 'Typhlosion')],
#  [(1, '#0158', 'Water', 'Totodile'),
#   (2, '#0159', 'Water', 'Croconaw'),
#   (3, '#0160', 'Water', 'Feraligatr')],
#  [(1, '#0161', 'Normal', 'Sentret'), (2, '#0162', 'Normal', 'Furret')],
#  [(1, '#0163', 'Normal · Flying', 'Hoothoot'),
#   (2, '#0164', 'Normal · Flying', 'Noctowl')],
#  [(1, '#0165', 'Bug · Flying', 'Ledyba'),
#   (2, '#0166', 'Bug · Flying', 'Ledian')],
#  [(1, '#0167', 'Bug · Poison', 'Spinarak'),
#   (2, '#0168', 'Bug · Poison', 'Ariados')],
#  [(1, '#0170', 'Water · Electric', 'Chinchou'),
#   (2, '#0171', 'Water · Electric', 'Lanturn')],
#  [(1, '#0175', 'Fairy', 'Togepi'), (2, '#0176', 'Fairy · Flying', 'Togetic')],
#  [(1, '#0177', 'Psychic · Flying', 'Natu'),
#   (2, '#0178', 'Psychic · Flying', 'Xatu')],
#  [(1, '#0179', 'Electric', 'Mareep'),
#   (2, '#0180', 'Electric', 'Flaaffy'),
#   (3, '#0181', 'Electric', 'Ampharos')],
#  [(2, '#0183', 'Water · Fairy', 'Marill'),
#   (3, '#0184', 'Water · Fairy', 'Azumarill')],
#  [(1, '#0187', 'Grass · Flying', 'Hoppip'),
#   (2, '#0188', 'Grass · Flying', 'Skiploom'),
#   (3, '#0189', 'Grass · Flying', 'Jumpluff')],
#  [(1, '#0191', 'Grass', 'Sunkern'), (2, '#0192', 'Grass', 'Sunflora')],
#  [(1, '#0194', 'Water · Ground', 'Wooper'),
#   (2, '#0195', 'Water · Ground', 'Quagsire')],
#  [(1, '#0204', 'Bug', 'Pineco'), (2, '#0205', 'Bug · Steel', 'Forretress')],
#  [(1, '#0209', 'Fairy', 'Snubbull'), (2, '#0210', 'Fairy', 'Granbull')],
#  [(1, '#0216', 'Normal', 'Teddiursa'), (2, '#0217', 'Normal', 'Ursaring')],
#  [(1, '#0218', 'Fire', 'Slugma'), (2, '#0219', 'Fire · Rock', 'Magcargo')],
#  [(1, '#0220', 'Ice · Ground', 'Swinub'),
#   (2, '#0221', 'Ice · Ground', 'Piloswine')],
#  [(1, '#0223', 'Water', 'Remoraid'), (2, '#0224', 'Water', 'Octillery')],
#  [(1, '#0228', 'Dark · Fire', 'Houndour'),
#   (2, '#0229', 'Dark · Fire', 'Houndoom')],
#  [(1, '#0231', 'Ground', 'Phanpy'), (2, '#0232', 'Ground', 'Donphan')],
#  [(1, '#0246', 'Rock · Ground', 'Larvitar'),
#   (2, '#0247', 'Rock · Ground', 'Pupitar'),
#   (3, '#0248', 'Rock · Dark', 'Tyranitar')]]

# %% [markdown]
# **Paso 5: mejorar nuestro conjunto de datos existente**
#
# Para el análisis me gustaría poder decir qué Pokémon son la última evolución de cada aarreglo y qué Pokémon no tienen evolución (y por lo tanto no se incluyeron en la lista en absoluto).
#
# * Por ejemplo: Charmander es el primero en el árbol de evolución Charmander-Charmeleon-Charizard y me gustaría excluirlo del análisis. Snorlax por otro lado no tiene evolución y me gustaría incluirlo en el análisis.
#
# Por tanto, me gustaría crear 2 listas, una con todos los pokémon que pertenecen a una rama de evolución y otra con pokémon que son los últimos de una rama de evolución.

# %%
#Extraer todos los pokemon de la lista step_3
# has_evolution = [[elem[3] for elem in branch_list ] for branch_list in step_3] 
has_evolution = [[elem[3] for elem in branch_list[:-1] ]  for branch_list in step_3 ] 
has_evolution
# Out:
# [['Bulbasaur', 'Ivysaur'],
#  ['Charmander', 'Charmeleon'],
#  ['Squirtle', 'Wartortle'],
#  ['Caterpie', 'Metapod'],
#  ['Weedle', 'Kakuna'],
#  ['Pidgey', 'Pidgeotto'],
#  ['Rattata'],
#  ['Rattata'],
#  ['Spearow'],
#  ['Ekans'],
#  ['Pichu', 'Pikachu', 'Raichu'],
#  ['Sandshrew'],
#  ['Sandshrew'],
#  ['Nidoran♀', 'Nidorina'],
#  ['Nidoran♂', 'Nidorino'],
#  ['Cleffa', 'Clefairy'],
#  ['Vulpix'],
#  ['Vulpix'],
#  ['Igglybuff', 'Jigglypuff'],
#  ['Zubat', 'Golbat'],
#  ['Oddish', 'Gloom', 'Vileplume'],
#  ['Paras'],
#  ['Venonat'],
#  ['Diglett'],
#  ['Diglett'],
#  ['Meowth'],
#  ['Meowth'],
#  ['Psyduck'],
#  ['Mankey'],
#  ['Growlithe'],
#  ['Growlithe'],
#  ['Poliwag', 'Poliwhirl', 'Poliwrath'],
#  ['Abra', 'Kadabra'],
#  ['Machop', 'Machoke'],
#  ['Bellsprout', 'Weepinbell'],
#  ['Tentacool'],
#  ['Geodude', 'Graveler'],
#  ['Geodude', 'Graveler'],
#  ['Ponyta'],
#  ['Ponyta'],
#  ['Slowpoke', 'Slowbro'],
#  ['Slowpoke', 'Slowbro'],
#  ['Magnemite'],
#  ['Doduo'],
#  ['Seel'],
#  ['Grimer'],
#  ['Grimer'],
#  ['Shellder'],
#  ['Gastly', 'Haunter'],
#  ['Onix'],
#  ['Drowzee'],
#  ['Krabby'],
#  ['Voltorb'],
#  ['Voltorb'],
#  ['Exeggcute', 'Exeggutor'],
#  ['Cubone', 'Marowak'],
#  ['Tyrogue', 'Hitmonlee', 'Hitmonchan'],
#  ['Koffing', 'Weezing'],
#  ['Rhyhorn'],
#  ['Chansey'],
#  ['Horsea', 'Seadra'],
#  ['Goldeen'],
#  ['Staryu'],
#  ['Mr. Mime'],
#  ['Scyther'],
#  ['Smoochum'],
#  ['Elekid'],
#  ['Magby'],
#  ['Magikarp'],
#  ['Eevee', 'Vaporeon', 'Jolteon'],
#  ['Eevee', 'Espeon'],
#  ['Porygon'],
#  ['Omanyte'],
#  ['Kabuto'],
#  ['Dratini', 'Dragonair'],
#  ['Chikorita', 'Bayleef'],
#  ['Cyndaquil', 'Quilava', 'Typhlosion'],
#  ['Totodile', 'Croconaw'],
#  ['Sentret'],
#  ['Hoothoot'],
#  ['Ledyba'],
#  ['Spinarak'],
#  ['Chinchou'],
#  ['Togepi'],
#  ['Natu'],
#  ['Mareep', 'Flaaffy'],
#  ['Marill'],
#  ['Hoppip', 'Skiploom'],
#  ['Sunkern'],
#  ['Wooper'],
#  ['Pineco'],
#  ['Snubbull'],
#  ['Teddiursa'],
#  ['Slugma'],
#  ['Swinub'],
#  ['Remoraid'],
#  ['Houndour'],
#  ['Phanpy'],
#  ['Larvitar', 'Pupitar']]

# %%
#Transformar la lista anterior en un arreglo de 1 dimension

# equipo: cómo se haría con dos for anidados:

#one_dim_names = []
#for evolution in has_evolution:
#   for pokemon in evolution:
#        one_dim_names.append(pokemon)
#has_evolution = one_dim_names

# %%
# equipo: ahoira con una list comprehension:

#Transformar la lista anterior en un arreglo de 1 dimension

#one_dim_names = [   p for evo in has_evolution for p in evo ]
#has_evolution = one_dim_names

# %%
#Transformar la lista anterior en un arreglo de 1 dimension

# equipo: ahora con sum:
one_dim_names = sum(has_evolution, [])
has_evolution = one_dim_names
has_evolution
# Out:
# ['Bulbasaur',
#  'Ivysaur',
#  'Charmander',
#  'Charmeleon',
#  'Squirtle',
#  'Wartortle',
#  'Caterpie',
#  'Metapod',
#  'Weedle',
#  'Kakuna',
#  'Pidgey',
#  'Pidgeotto',
#  'Rattata',
#  'Rattata',
#  'Spearow',
#  'Ekans',
#  'Pichu',
#  'Pikachu',
#  'Raichu',
#  'Sandshrew',
#  'Sandshrew',
#  'Nidoran♀',
#  'Nidorina',
#  'Nidoran♂',
#  'Nidorino',
#  'Cleffa',
#  'Clefairy',
#  'Vulpix',
#  'Vulpix',
#  'Igglybuff',
#  'Jigglypuff',
#  'Zubat',
#  'Golbat',
#  'Oddish',
#  'Gloom',
#  'Vileplume',
#  'Paras',
#  'Venonat',
#  'Diglett',
#  'Diglett',
#  'Meowth',
#  'Meowth',
#  'Psyduck',
#  'Mankey',
#  'Growlithe',
#  'Growlithe',
#  'Poliwag',
#  'Poliwhirl',
#  'Poliwrath',
#  'Abra',
#  'Kadabra',
#  'Machop',
#  'Machoke',
#  'Bellsprout',
#  'Weepinbell',
#  'Tentacool',
#  'Geodude',
#  'Graveler',
#  'Geodude',
#  'Graveler',
#  'Ponyta',
#  'Ponyta',
#  'Slowpoke',
#  'Slowbro',
#  'Slowpoke',
#  'Slowbro',
#  'Magnemite',
#  'Doduo',
#  'Seel',
#  'Grimer',
#  'Grimer',
#  'Shellder',
#  'Gastly',
#  'Haunter',
#  'Onix',
#  'Drowzee',
#  'Krabby',
#  'Voltorb',
#  'Voltorb',
#  'Exeggcute',
#  'Exeggutor',
#  'Cubone',
#  'Marowak',
#  'Tyrogue',
#  'Hitmonlee',
#  'Hitmonchan',
#  'Koffing',
#  'Weezing',
#  'Rhyhorn',
#  'Chansey',
#  'Horsea',
#  'Seadra',
#  'Goldeen',
#  'Staryu',
#  'Mr. Mime',
#  'Scyther',
#  'Smoochum',
#  'Elekid',
#  'Magby',
#  'Magikarp',
#  'Eevee',
#  'Vaporeon',
#  'Jolteon',
#  'Eevee',
#  'Espeon',
#  'Porygon',
#  'Omanyte',
#  'Kabuto',
#  'Dratini',
#  'Dragonair',
#  'Chikorita',
#  'Bayleef',
#  'Cyndaquil',
#  'Quilava',
#  'Typhlosion',
#  'Totodile',
#  'Croconaw',
#  'Sentret',
#  'Hoothoot',
#  'Ledyba',
#  'Spinarak',
#  'Chinchou',
#  'Togepi',
#  'Natu',
#  'Mareep',
#  'Flaaffy',
#  'Marill',
#  'Hoppip',
#  'Skiploom',
#  'Sunkern',
#  'Wooper',
#  'Pineco',
#  'Snubbull',
#  'Teddiursa',
#  'Slugma',
#  'Swinub',
#  'Remoraid',
#  'Houndour',
#  'Phanpy',
#  'Larvitar',
#  'Pupitar']

# %%
#Tomar la última entrada de la lista
last_evolutions  = [x[-1] for x in step_3] 
last_evolutions
# Out:
# [(3, '#0003', 'Grass · Poison', 'Venusaur'),
#  (3, '#0006', 'Fire · Flying', 'Charizard'),
#  (3, '#0009', 'Water', 'Blastoise'),
#  (3, '#0012', 'Bug · Flying', 'Butterfree'),
#  (3, '#0015', 'Bug · Poison', 'Beedrill'),
#  (3, '#0018', 'Normal · Flying', 'Pidgeot'),
#  (2, '#0020', 'Normal', 'Raticate'),
#  (2, '#0020', 'Alolan Raticate', 'Raticate'),
#  (2, '#0022', 'Normal · Flying', 'Fearow'),
#  (2, '#0024', 'Poison', 'Arbok'),
#  (4, '#0026', 'Alolan Raichu', 'Raichu'),
#  (2, '#0028', 'Ground', 'Sandslash'),
#  (2, '#0028', 'Alolan Sandslash', 'Sandslash'),
#  (3, '#0031', 'Poison · Ground', 'Nidoqueen'),
#  (3, '#0034', 'Poison · Ground', 'Nidoking'),
#  (3, '#0036', 'Fairy', 'Clefable'),
#  (2, '#0038', 'Fire', 'Ninetales'),
#  (2, '#0038', 'Alolan Ninetales', 'Ninetales'),
#  (3, '#0040', 'Normal · Fairy', 'Wigglytuff'),
#  (3, '#0169', 'Poison · Flying', 'Crobat'),
#  (4, '#0182', 'Grass', 'Bellossom'),
#  (2, '#0047', 'Bug · Grass', 'Parasect'),
#  (2, '#0049', 'Bug · Poison', 'Venomoth'),
#  (2, '#0051', 'Ground', 'Dugtrio'),
#  (2, '#0051', 'Alolan Dugtrio', 'Dugtrio'),
#  (2, '#0053', 'Normal', 'Persian'),
#  (2, '#0053', 'Alolan Persian', 'Persian'),
#  (2, '#0055', 'Water', 'Golduck'),
#  (2, '#0057', 'Fighting', 'Primeape'),
#  (2, '#0059', 'Fire', 'Arcanine'),
#  (2, '#0059', 'Hisuian Arcanine', 'Arcanine'),
#  (4, '#0186', 'Water', 'Politoed'),
#  (3, '#0065', 'Psychic', 'Alakazam'),
#  (3, '#0068', 'Fighting', 'Machamp'),
#  (3, '#0071', 'Grass · Poison', 'Victreebel'),
#  (2, '#0073', 'Water · Poison', 'Tentacruel'),
#  (3, '#0076', 'Rock · Ground', 'Golem'),
#  (3, '#0076', 'Alolan Golem', 'Golem'),
#  (2, '#0078', 'Fire', 'Rapidash'),
#  (2, '#0078', 'Galarian Rapidash', 'Rapidash'),
#  (3, '#0199', 'Water · Psychic', 'Slowking'),
#  (3, '#0199', 'Galarian Slowking', 'Slowking'),
#  (2, '#0082', 'Electric · Steel', 'Magneton'),
#  (2, '#0085', 'Normal · Flying', 'Dodrio'),
#  (2, '#0087', 'Water · Ice', 'Dewgong'),
#  (2, '#0089', 'Poison', 'Muk'),
#  (2, '#0089', 'Alolan Muk', 'Muk'),
#  (2, '#0091', 'Water · Ice', 'Cloyster'),
#  (3, '#0094', 'Ghost · Poison', 'Gengar'),
#  (2, '#0208', 'Steel · Ground', 'Steelix'),
#  (2, '#0097', 'Psychic', 'Hypno'),
#  (2, '#0099', 'Water', 'Kingler'),
#  (2, '#0101', 'Electric', 'Electrode'),
#  (2, '#0101', 'Hisuian Electrode', 'Electrode'),
#  (3, '#0103', 'Alolan Exeggutor', 'Exeggutor'),
#  (3, '#0105', 'Alolan Marowak', 'Marowak'),
#  (4, '#0237', 'Fighting', 'Hitmontop'),
#  (3, '#0110', 'Galarian Weezing', 'Weezing'),
#  (2, '#0112', 'Ground · Rock', 'Rhydon'),
#  (3, '#0242', 'Normal', 'Blissey'),
#  (3, '#0230', 'Water · Dragon', 'Kingdra'),
#  (2, '#0119', 'Water', 'Seaking'),
#  (2, '#0121', 'Water · Psychic', 'Starmie'),
#  (3, '#0122', 'Galarian Mr. Mime', 'Mr. Mime'),
#  (2, '#0212', 'Bug · Steel', 'Scizor'),
#  (2, '#0124', 'Ice · Psychic', 'Jynx'),
#  (2, '#0125', 'Electric', 'Electabuzz'),
#  (2, '#0126', 'Fire', 'Magmar'),
#  (2, '#0130', 'Water · Flying', 'Gyarados'),
#  (4, '#0136', 'Fire', 'Flareon'),
#  (3, '#0197', 'Dark', 'Umbreon'),
#  (2, '#0233', 'Normal', 'Porygon2'),
#  (2, '#0139', 'Rock · Water', 'Omastar'),
#  (2, '#0141', 'Rock · Water', 'Kabutops'),
#  (3, '#0149', 'Dragon · Flying', 'Dragonite'),
#  (3, '#0154', 'Grass', 'Meganium'),
#  (4, '#0157', 'Hisuian Typhlosion', 'Typhlosion'),
#  (3, '#0160', 'Water', 'Feraligatr'),
#  (2, '#0162', 'Normal', 'Furret'),
#  (2, '#0164', 'Normal · Flying', 'Noctowl'),
#  (2, '#0166', 'Bug · Flying', 'Ledian'),
#  (2, '#0168', 'Bug · Poison', 'Ariados'),
#  (2, '#0171', 'Water · Electric', 'Lanturn'),
#  (2, '#0176', 'Fairy · Flying', 'Togetic'),
#  (2, '#0178', 'Psychic · Flying', 'Xatu'),
#  (3, '#0181', 'Electric', 'Ampharos'),
#  (3, '#0184', 'Water · Fairy', 'Azumarill'),
#  (3, '#0189', 'Grass · Flying', 'Jumpluff'),
#  (2, '#0192', 'Grass', 'Sunflora'),
#  (2, '#0195', 'Water · Ground', 'Quagsire'),
#  (2, '#0205', 'Bug · Steel', 'Forretress'),
#  (2, '#0210', 'Fairy', 'Granbull'),
#  (2, '#0217', 'Normal', 'Ursaring'),
#  (2, '#0219', 'Fire · Rock', 'Magcargo'),
#  (2, '#0221', 'Ice · Ground', 'Piloswine'),
#  (2, '#0224', 'Water', 'Octillery'),
#  (2, '#0229', 'Dark · Fire', 'Houndoom'),
#  (2, '#0232', 'Ground', 'Donphan'),
#  (3, '#0248', 'Rock · Dark', 'Tyranitar')]

# %%
#Aquellos que tienen 2 evoluciones finales (Politoed y Poliwrath, por ejemplo)
last_evolutions.extend([x[-2] for x in step_3 if x[-1][0] == 4])
last_evolutions
# Out:
# [(3, '#0003', 'Grass · Poison', 'Venusaur'),
#  (3, '#0006', 'Fire · Flying', 'Charizard'),
#  (3, '#0009', 'Water', 'Blastoise'),
#  (3, '#0012', 'Bug · Flying', 'Butterfree'),
#  (3, '#0015', 'Bug · Poison', 'Beedrill'),
#  (3, '#0018', 'Normal · Flying', 'Pidgeot'),
#  (2, '#0020', 'Normal', 'Raticate'),
#  (2, '#0020', 'Alolan Raticate', 'Raticate'),
#  (2, '#0022', 'Normal · Flying', 'Fearow'),
#  (2, '#0024', 'Poison', 'Arbok'),
#  (4, '#0026', 'Alolan Raichu', 'Raichu'),
#  (2, '#0028', 'Ground', 'Sandslash'),
#  (2, '#0028', 'Alolan Sandslash', 'Sandslash'),
#  (3, '#0031', 'Poison · Ground', 'Nidoqueen'),
#  (3, '#0034', 'Poison · Ground', 'Nidoking'),
#  (3, '#0036', 'Fairy', 'Clefable'),
#  (2, '#0038', 'Fire', 'Ninetales'),
#  (2, '#0038', 'Alolan Ninetales', 'Ninetales'),
#  (3, '#0040', 'Normal · Fairy', 'Wigglytuff'),
#  (3, '#0169', 'Poison · Flying', 'Crobat'),
#  (4, '#0182', 'Grass', 'Bellossom'),
#  (2, '#0047', 'Bug · Grass', 'Parasect'),
#  (2, '#0049', 'Bug · Poison', 'Venomoth'),
#  (2, '#0051', 'Ground', 'Dugtrio'),
#  (2, '#0051', 'Alolan Dugtrio', 'Dugtrio'),
#  (2, '#0053', 'Normal', 'Persian'),
#  (2, '#0053', 'Alolan Persian', 'Persian'),
#  (2, '#0055', 'Water', 'Golduck'),
#  (2, '#0057', 'Fighting', 'Primeape'),
#  (2, '#0059', 'Fire', 'Arcanine'),
#  (2, '#0059', 'Hisuian Arcanine', 'Arcanine'),
#  (4, '#0186', 'Water', 'Politoed'),
#  (3, '#0065', 'Psychic', 'Alakazam'),
#  (3, '#0068', 'Fighting', 'Machamp'),
#  (3, '#0071', 'Grass · Poison', 'Victreebel'),
#  (2, '#0073', 'Water · Poison', 'Tentacruel'),
#  (3, '#0076', 'Rock · Ground', 'Golem'),
#  (3, '#0076', 'Alolan Golem', 'Golem'),
#  (2, '#0078', 'Fire', 'Rapidash'),
#  (2, '#0078', 'Galarian Rapidash', 'Rapidash'),
#  (3, '#0199', 'Water · Psychic', 'Slowking'),
#  (3, '#0199', 'Galarian Slowking', 'Slowking'),
#  (2, '#0082', 'Electric · Steel', 'Magneton'),
#  (2, '#0085', 'Normal · Flying', 'Dodrio'),
#  (2, '#0087', 'Water · Ice', 'Dewgong'),
#  (2, '#0089', 'Poison', 'Muk'),
#  (2, '#0089', 'Alolan Muk', 'Muk'),
#  (2, '#0091', 'Water · Ice', 'Cloyster'),
#  (3, '#0094', 'Ghost · Poison', 'Gengar'),
#  (2, '#0208', 'Steel · Ground', 'Steelix'),
#  (2, '#0097', 'Psychic', 'Hypno'),
#  (2, '#0099', 'Water', 'Kingler'),
#  (2, '#0101', 'Electric', 'Electrode'),
#  (2, '#0101', 'Hisuian Electrode', 'Electrode'),
#  (3, '#0103', 'Alolan Exeggutor', 'Exeggutor'),
#  (3, '#0105', 'Alolan Marowak', 'Marowak'),
#  (4, '#0237', 'Fighting', 'Hitmontop'),
#  (3, '#0110', 'Galarian Weezing', 'Weezing'),
#  (2, '#0112', 'Ground · Rock', 'Rhydon'),
#  (3, '#0242', 'Normal', 'Blissey'),
#  (3, '#0230', 'Water · Dragon', 'Kingdra'),
#  (2, '#0119', 'Water', 'Seaking'),
#  (2, '#0121', 'Water · Psychic', 'Starmie'),
#  (3, '#0122', 'Galarian Mr. Mime', 'Mr. Mime'),
#  (2, '#0212', 'Bug · Steel', 'Scizor'),
#  (2, '#0124', 'Ice · Psychic', 'Jynx'),
#  (2, '#0125', 'Electric', 'Electabuzz'),
#  (2, '#0126', 'Fire', 'Magmar'),
#  (2, '#0130', 'Water · Flying', 'Gyarados'),
#  (4, '#0136', 'Fire', 'Flareon'),
#  (3, '#0197', 'Dark', 'Umbreon'),
#  (2, '#0233', 'Normal', 'Porygon2'),
#  (2, '#0139', 'Rock · Water', 'Omastar'),
#  (2, '#0141', 'Rock · Water', 'Kabutops'),
#  (3, '#0149', 'Dragon · Flying', 'Dragonite'),
#  (3, '#0154', 'Grass', 'Meganium'),
#  (4, '#0157', 'Hisuian Typhlosion', 'Typhlosion'),
#  (3, '#0160', 'Water', 'Feraligatr'),
#  (2, '#0162', 'Normal', 'Furret'),
#  (2, '#0164', 'Normal · Flying', 'Noctowl'),
#  (2, '#0166', 'Bug · Flying', 'Ledian'),
#  (2, '#0168', 'Bug · Poison', 'Ariados'),
#  (2, '#0171', 'Water · Electric', 'Lanturn'),
#  (2, '#0176', 'Fairy · Flying', 'Togetic'),
#  (2, '#0178', 'Psychic · Flying', 'Xatu'),
#  (3, '#0181', 'Electric', 'Ampharos'),
#  (3, '#0184', 'Water · Fairy', 'Azumarill'),
#  (3, '#0189', 'Grass · Flying', 'Jumpluff'),
#  (2, '#0192', 'Grass', 'Sunflora'),
#  (2, '#0195', 'Water · Ground', 'Quagsire'),
#  (2, '#0205', 'Bug · Steel', 'Forretress'),
#  (2, '#0210', 'Fairy', 'Granbull'),
#  (2, '#0217', 'Normal', 'Ursaring'),
#  (2, '#0219', 'Fire · Rock', 'Magcargo'),
#  (2, '#0221', 'Ice · Ground', 'Piloswine'),
#  (2, '#0224', 'Water', 'Octillery'),
#  (2, '#0229', 'Dark · Fire', 'Houndoom'),
#  (2, '#0232', 'Ground', 'Donphan'),
#  (3, '#0248', 'Rock · Dark', 'Tyranitar'),
#  (3, '#0026', 'Electric', 'Raichu'),
#  (3, '#0045', 'Grass · Poison', 'Vileplume'),
#  (3, '#0062', 'Water · Fighting', 'Poliwrath'),
#  (3, '#0107', 'Fighting', 'Hitmonchan'),
#  (3, '#0135', 'Electric', 'Jolteon'),
#  (3, '#0157', 'Fire', 'Typhlosion')]

# %%
#Hay algunos elementos que tienen multiples entradas
eevee_and_hitmon = [x[1:] for x in step_3 if (x[0][3] == 'Tyrogue') or (x[0][3] ==  'Eevee')]
eevee_and_hitmon = sum(eevee_and_hitmon, [])
last_evolutions.extend(eevee_and_hitmon)

#Se remueven algunos duplicados
last_evo_df = pd.DataFrame([[int(x[1][1:]), x[3]] for x in last_evolutions], columns=['Number', 'Pokemon'] )
last_evo_df = last_evo_df.drop_duplicates() 
last_evo_df.shape
# Out:
# (95, 2)

# %% [markdown]
# Estamos al final del proceso, tenemos una lista de Pokémon que pertenecen a una rama de evolución y también tenemos una lista de Pokémon que son las últimas evoluciones. Sigamos adelante y actualicemos nuestro conjunto de datos inicial. Crearemos dos columnas adicionales.

# %%
my_pokemon = gens1and2.copy()

my_pokemon['Has_evol'] = my_pokemon.Name.isin(has_evolution)
my_pokemon['Last_evol'] = my_pokemon.Name.isin(last_evo_df.Pokemon)
my_evolved_pokemon = my_pokemon.loc[(my_pokemon.Last_evol == True) | (my_pokemon.Has_evol == False)].copy()

# %%
my_pokemon[['Name','Has_evol','Last_evol']]
# Out:
#            Name  Has_evol  Last_evol
# 0     Bulbasaur      True      False
# 1       Ivysaur      True      False
# 2      Venusaur     False       True
# 4    Charmander      True      False
# 5    Charmeleon      True      False
# ..          ...       ...        ...
# 266     Pupitar      True      False
# 267   Tyranitar     False       True
# 269       Lugia     False      False
# 270       Ho-oh     False      False
# 271      Celebi     False      False
#
# [251 rows x 3 columns]

# %%
#my_pokemon.to_csv('out')
my_evolved_pokemon.shape
# Out:
# (137, 14)

# %%
(f, axes) = attr_per_type(my_evolved_pokemon, ['HP','Defense','Sp. Def','Speed','Attack','Sp. Atk'], 'Legendary','Type 1')
plt.show()

# %%
#Grafica ahora con el dataframe limpio
#<Completar>
#<Completar>

# %% [markdown]
# Estos son los Pokémon reales que podrían usarse en una batalla de Pokémon, ya que tener una evolución significa que tus estadísticas aumentarán y tendrás acceso a un grupo de movimientos más amplio. Ahora, sería interesante plotear las frecuencias de los Tipos 1 y 2 que tenemos en este data set.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))
plt.rcParams["font.size"] = 12

ax1 = my_evolved_pokemon.groupby('Type 1').size().sort_values().plot(kind='barh', ax=ax1)
start, end = ax1.get_xlim()
ax1.xaxis.set_ticks(np.arange(start, end, 5))
ax1.axes.get_yaxis().get_label().set_visible(False)
_ = ax1.set_title('Type 1 frequency')

# Lo mismo, pero para el Type 2
ax2 = my_evolved_pokemon.groupby('Type 2').size().sort_values().plot(kind='barh', ax=ax2)

# %% [markdown]
# Ahora, para fines didácticos realizaremos un heatmap haciendo un conteo de ambos, mostrando aquellas combinaciones de tipos

# %%
pivot_dat = my_evolved_pokemon.pivot_table(index=my_evolved_pokemon['Type 1'],
                                           columns=my_evolved_pokemon['Type 2'], 
                                               aggfunc = 'size')


pivot_dat = pivot_dat[pivot_dat.sum().sort_values(ascending = False).index] #Reordering
        
sns.heatmap(pivot_dat, 
            annot=True, 
            cmap=sns.color_palette('mako'), 
            cbar=True, 
            linewidths=0.3)
plt.show()

# %% [markdown]
# ## Nota del equipo: en nuestra pivot table llegamos a tener un valor de 6 que no tiene el código de ejemplo

# %%
pivot_dat = my_evolved_pokemon.pivot_table(index=my_evolved_pokemon['Type 1'],
                                           columns=my_evolved_pokemon['Type 2'], 
                                           aggfunc = 'size')
#pivot_dat = pivot_dat[<#completar>.sum().sort_values(ascending = False).index] #Reordering
sns.heatmap(pivot_dat, 
            annot=True, 
            cmap=<#completar>, 
            cbar=<#completar>, 
            linewidths=0.3)
plt.show()

# %% [markdown]
# Ahora, mostremos la distribución de los datos utilizando el método de displot

# %%
stats = my_evolved_pokemon.loc[:, 'HP':'Speed']
stats
# Out:
#       HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 2     80      82       83      100      100     80
# 6     78      84       78      109       85    100
# 11    79      83      100       85      105     78
# 15    60      45       50       90       80     70
# 18    65      90       40       45       80     75
# ..   ...     ...      ...      ...      ...    ...
# 264  100      75      115       90      115     85
# 267  100     134      110       95      100     61
# 269  106      90      130       90      154    110
# 270  106     130       90      110      154     90
# 271  100     100      100      100      100    100
#
# [137 rows x 6 columns]

# %%
stats = my_evolved_pokemon.loc[:, 'HP':'Speed']
plt.figure(figsize=(25, 20))

for ii, stat in enumerate(stats):
    #title = "Distributions of {stat}".format(stat=stat)
    title = "Distributions of "+stat
    plt.subplot(3, 3, ii+1)
    #plt.title('prueba')
    sns.distplot(stats.stat)
    x = plt.gca().get_xlim()[1] * .6
    y = plt.gca().get_ylim()[1] * .9
    plt.text(x, y, '$\mu: {mu: .2f}, \sigma: {sigma: .2f}$'.format(mu = 99, sigma=99))
    
    
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [292], in <cell line: 4>()
#       7 plt.subplot(3, 3, ii+1)
#       8 #plt.title('prueba')
# ----> 9 sns.distplot(stats.stat)
#      10 x = plt.gca().get_xlim()[1] * .6
#      11 y = plt.gca().get_ylim()[1] * .9
#
# File /mnt/LENG/dev/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'stat'

# %%
stats.iloc[0]
# Out:
# HP          80
# Attack      82
# Defense     83
# Sp. Atk    100
# Sp. Def    100
# Speed       80
# Name: 2, dtype: int64

# %% [markdown]
# ## Equipo: Aquí nos quedamos el sábado 11 de Marzo

# %%
stats = my_evolved_pokemon.loc[:, 'HP':'Speed']
plt.figure(figsize=(25, 20))

for ii, stat in enumerate(stats):
    print(type(stat),ii)
    title = "Distributions of {stat}".format(
        stat = stat
    )
    
    plt.subplot(3, 3, ii+1)
    #plt.title(stat)
    plt.suptitle(stat)
    sns.distplot(stats[stat])
    x = plt.gca().get_xlim()[1] * .6
    y = plt.gca().get_ylim()[1] * .9
    plt.text(x, y, '$\mu: {mu: .2f}, \sigma: {sigma: .2f}$'.format(mu = stats[stat].mean(), sigma=stats[stat].std()))
    
    
plt.tight_layout()
plt.show()
# Out:
# <class 'str'> 0
# <class 'str'> 1
# /mnt/LENG/dev/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /mnt/LENG/dev/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <class 'str'> 2
# <class 'str'> 3
# /mnt/LENG/dev/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /mnt/LENG/dev/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <class 'str'> 4
# <class 'str'> 5
# /mnt/LENG/dev/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /mnt/LENG/dev/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Modelos para saber si son o no legendarios

# %%
<#completar>
# Out:
# array([False,  True])

# %% [markdown]
# Vamos a realizar un descarte de columnas.
#
# Para X, solamente necesitaremos las columnas de características junto con su valor total (deberán ser 7 columnas)
#
# Para Y, necesitamos la columna de legendarios ya que será nuestro objetivo.

# %%
X = <#completar>
y = <#completar>

# %% [markdown]
# Por primera ocasión, estaremos utilizando la librería de sklearn para auxiliarnos en hacer el split de datos

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y) # 80% y 20%

# %% [markdown]
# Estaremos utilizando por primera vez, algunos modelos como son la regresión logística, las máquinas de soporte vectorial, árboles de decisión y bosque aleatorio

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier as DT
from sklearn.ensemble import RandomForestClassifier as RF

alg1 = LogisticRegression()
alg2 = SVC(kernel = 'rbf') #lineal , polinomial, radial basis fuction (gaussiano)
alg3 = RF()
alg4 = DT()

# %% [markdown]
# Posteriormente, entrenaremos cada uno de los modelos.
# Para obtener el valor del "Accuracy" (Exactitud), necesitamos comparar el valor original de ambos sets contra el valor predicho del algoritmo

# %%
from sklearn.metrics import accuracy_score
alg1.fit(<#completar>)

pd.DataFrame({"Accuracy on Train":[accuracy_score(<#completar>)],
    "Accuracy on Test":<#completar>})
# Out:
#    Accurancy on Train  Accurancy on Test
# 0            0.978723           0.936508

# %%
alg2.<#completar>
# Out:
#    Accurancy on Train  Accurancy on Test
# 0            0.978723           0.968254

# %%
alg3.<#completar>
# Out:
#    Accurancy on Train  Accurancy on Test
# 0                 1.0           0.984127

# %%
alg4.<#completar>
# Out:
#    Accurancy on Train  Accurancy on Test
# 0                 1.0           0.984127

# %% [markdown]
# Vamos a probar ahora nuestros modelos. Usaremos a estos ejemplos para observar si los modelos pueden realizar una buena predicción de si es o no un legendario.
#
# El siguiente ejemplo no debería ser clasificado como legendario...

# %%
#Completar
# Out:
#                         Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                  Bulbasaur  Grass  Poison    318  45      49       49
# 1                    Ivysaur  Grass  Poison    405  60      62       63
# 2                   Venusaur  Grass  Poison    525  80      82       83
# 3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4                 Charmander   Fire     NaN    309  39      52       43
# 5                 Charmeleon   Fire     NaN    405  58      64       58
# 6                  Charizard   Fire  Flying    534  78      84       78
# 7  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %%
#Completar
# Out:
# array([[634, 78, 104, 78, 159, 115, 100]], dtype=object)

# %%
# Mandamos a llamar a los algoritmos con el np.array que obtuvimos 
# del registro en específico y sus caracteristicas correspondientes
alg1.predict(test)[0]
# Out:
# C:\Users\beyon\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# True

# %%
alg2.predict(test)[0]
# Out:
# C:\Users\beyon\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# False

# %%
alg3.predict(test)[0]
# Out:
# C:\Users\beyon\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# True

# %%
alg4.predict(test)[0]
# Out:
# C:\Users\beyon\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# True

# %% [markdown]
# ### ¿Podrían tratar de dar una idea de porque en algunos casos los modelos se han equivocado?

# %% [markdown]
# ---
# ---
#
# ### Extender ejercicio para otras categorías usando pokedex_v2
#
# Ahora, usaremos el archivo csv de pokedex_v2 para hacer otro pequeño ejercicio. La diferencia de este archivo es que tiene la columna de "status" con otras clasificaciones a diferencia de "Legendary" que solamente era True o False

# %%
#Lectura de datos

# %% [markdown]
# Del mismo modo, construiremos nuestros conjuntos X y Y para hacer un ejercicio con estos datos. Pero ahora, Y tendrá que ser otra variable objetivo

# %%
#Impresion de df
# Out:
#    pokedex_number           Name type_1  type_2  total_points  hp  attack  \
# 0               1      Bulbasaur  Grass  Poison           318  45      49
# 1               2        Ivysaur  Grass  Poison           405  60      62
# 2               3       Venusaur  Grass  Poison           525  80      82
# 3               3  Mega Venusaur  Grass  Poison           625  80     100
#
#    defense  sp_attack  sp_defense  speed  generation  status
# 0       49         65          65     45           1  Normal
# 1       63         80          80     60           1  Normal
# 2       83        100         100     80           1  Normal
# 3      123        122         120     80           1  Normal

# %%
#Split de X y y

# %%
#Imprimir y
# Out:
# 0          Normal
# 1          Normal
# 2          Normal
# 3          Normal
# 4          Normal
#           ...
# 1023    Legendary
# 1024    Legendary
# 1025    Legendary
# 1026    Legendary
# 1027    Legendary
# Name: status, Length: 1028, dtype: object

# %% [markdown]
# Si realizamos un conteo de valores de la generacion con respecto al status, podremos apreciar algo interesante. Está completamente desbalanceado!

# %%
#Value counts de generación vs status
# Out:
# generation         status      1      2      3      4      5     6     7     8
# 0               Legendary    3.0    2.0    6.0    4.0    5.0   5.0   8.0   6.0
# 1                Mythical    1.0    1.0    5.0    6.0    6.0   5.0   5.0   NaN
# 2                  Normal  185.0  101.0  147.0  105.0  151.0  75.0  69.0  82.0
# 3           Sub Legendary    3.0    3.0    7.0    6.0    9.0   NaN  17.0   NaN

# %% [markdown]
# Para este ejemplo, podríamos auxiliarnos un poco de una librería, dado que sí, efectivamente tenemos un poquito del desbalance de clases.
#
# Nos auxiliaremos de la librería [imbalanced-learn](https://imbalanced-learn.org/stable/user_guide.html#user-guide)

# %% [markdown]
# ¿Qué es lo que hace esta librería?, en resumen, nos ayuda a muestrear. Como si fuera una especie de generador de números aleatorios (Monte Carlo)

# %%
#!pip install imbalanced-learn

# %% [markdown]
# Esto significa que si la clase mayoritaria tuviera 1000 ejemplos y la clase minoritaria 100, esta estrategia sobremuestrearía la clase minoritaria para que tenga 1000 ejemplos.

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
oversample = RandomOverSampler(sampling_strategy='minority')
# fit and apply the transform
X_over, y_over = oversample.fit_resample(X, y)

# %% [markdown]
# Por ejemplo, un conjunto de datos con 1000 ejemplos en la clase mayoritaria y 100 ejemplos en la clase minoritaria se submuestreará de modo que ambas clases tengan 100 ejemplos en el conjunto de datos de entrenamiento transformado.

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
undersample = RandomUnderSampler(sampling_strategy='majority')

# %% [markdown]
# Luego, la transformación puede ajustarse y aplicarse a un conjunto de datos en un solo paso llamando a la función fit_resample () y pasando el conjunto de datos sin transformar como argumentos.

# %%
# fit and apply the transform
X_under, y_under = undersample.fit_resample(X, y)

# %% [markdown]
# Sus resultados pueden variar dada la naturaleza estocástica del algoritmo o procedimiento de evaluación, o las diferencias en la precisión numérica. Considera ejecutar el ejemplo varias veces y compara el resultado promedio.
#
# El modelo elegido y la configuración de remuestreo son arbitrarios, diseñados para proporcionar una plantilla que puede usar para probar el submuestreo con su conjunto de datos y algoritmo de aprendizaje en lugar de resolver de manera óptima el conjunto de datos sintéticos.
#
# Ahora, vuelvan a entrenar los modelos con estos datasets y volvamos a repetir el ejercicio anterior.
#
# 1.- Entrenar los modelos para los conjuntos X y Y considerando la columna de status. Prueben nuevamente los datos que usamos en la parte superior para observar que resultado ahora nos arroja.
#
# 2.- Realizar lo mismo, pero ahora con los conjuntos _over
#
# 3.- Realizar lo mismo, pero ahora con los conjuntos _under

# %% [markdown]
# ### ¿Mejoraron los resultados? Den una pequeña descripción de que fue lo que sucedió
